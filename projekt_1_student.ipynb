# %% [markdown]
# <a href="https://colab.research.google.com/github/aleksandraburakowska1/Maly_projekt3_Ola_i_Michal/blob/main/projekt_1_student.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Mały projekt 1: wizualizacja poziomu zanieczyszczeń (PM2.5)
#
# Główny Inspektorat Ochrony Środowiska (GIOS) udostępnia dane o jakości powietrza w Polsce na stronie [https://powietrze.gios.gov.pl](https://powietrze.gios.gov.pl), tj. poziom stężenia pyłów PM2.5, PM10, SO2 i innych zanieczyszczeń. Dane te są szczególnie przydatne w analizach środowiskowych i zdrowotnych. W tym zadaniu interesują nas godzinne pomiary stężeń drobnego pyłu **PM2.5** (pyłu o średnicy poniżej 2.5 µm) w latach **2014, 2019 i 2024**. Pyły PM2.5 są one bardzo szkodliwe dla zdrowia, gdyż mogąc przenikać głęboko do układu oddechowego i krwiobiegu. Zadanie polega na przeprowadzeniu analizy danych wraz z opisami czynności oraz wykresami.
#
# ## Wymagania ogólne
#
# - Rozwiązanie należy przygotować w formie **Jupyter Notebooka (`.ipynb`)**.  Rozwiązanie proszę przesłać przez Moodle’a.
# - Wszystkie operacje czyszczenia i łączenia danych wykonaj **programistycznie**, bez ręcznej edycji plików.
# - Do każdego punktu należy obowiązkowo dodać opis z analizą otrzymanych wyników.
# - Zadanie należy wykonać w wylosowanych parach. Obie osoby z pary przesyłają **identyczne pliki** i dodają na początku notebooka opis swojego wkładu.
# - Ocena jest wspólna dla pary, a nie indywidualna.
#
# ## Dane wejściowe i metadane
#
# - Każdy rok to archiwum ZIP dostępne pod adresem [https://powietrze.gios.gov.pl/pjp/archives/](https://powietrze.gios.gov.pl/pjp/archives/).
# - Wewnątrz znajdują się pliki Excel, np. `2024_PM25_1g.xlsx`.
# - Poniższa funkcja `download_gios_archive` pozwala odczytać odpowiedni zbior danych; resztę danych pomijamy.
# - Użyj pliku metadanych (dostępnego na tej samej stronie), aby zaktualizować **kody stacji** (część stacji mogła w międzyczasie zmienić nazwę). W metadanych znajdziesz odpowiednie kolumny.
#
# ## Zadania
#
# ### 1. Wczytanie i czyszczenie danych
#
# Wczytaj dane dla lat **2014, 2019 i 2024**, oczyścić je z niepotrzebnych wierszy oraz ujednolić ich format. Zaktualizuj stare kody stacji zgodnie z metadanymi. Pozostaw tylko stacje występujące we wszystkich trzech latach. Informacje o stacjach pomiarowych warto uzupełnić o miejscowości dostępne w metadanych, np. za pomocą MultiIndex: (miejscowość, kod stacji). Pomiary dokonane o północy (00:00:00) powinny być potraktowane jako dotyczące poprzedniego dnia. Połącz dane z trzech lat w jeden `DataFrame` i zapisz do pliku.
#
# ### 2. Średnie miesięczne + trend dla miast
#
# Oblicz średnie miesięczne stężenie PM2.5 dla każdej stacji i roku. Dla **Warszawy** i **Katowic**, po uśrednieniu po wszystkich stacjach z tych miast, narysuj wykres liniowy pokazujący trend średnich miesięcznych wartości PM2.5 w 2014 i 2024 roku. Oś X - miesiące (1-12); oś Y - średnia wartość PM2.5; 4 linie trendu. Dołącz opis i interpretację obserwowanych różnic.
#
# ### 3. Heatmapa miesięcznych średnich
#
# Dla każdej miejscowości przedstaw heatmapę średnich miesięcznych stężeń PM2.5 w latach lat 2014, 2019 i 2024 (oś X – miesiąc, oś Y – rok). Uśrednij wartości po wszystkich stacjach w danej miejscowości. Każdy panel (facet) ma odpowiadać jednej miejscowości. Dołącz interpretację obserwowanych wyników.
#
# ### 4. Dni z przekroczeniem normy (WHO)
#
# Dla każdej stacji i roku policz liczbę dni, w których wystąpiło przekroczenie dobowej normy stężenia PM2.5, czyli 15 µg/m³ (źródło: [https://airscan.org/new-who-air-quality-guidelines-2021/](https://airscan.org/new-who-air-quality-guidelines-2021/)). Znajdź 3 stacje z najmniejszą i 3 stacje z największą liczbą dni z przekroczeniem normy dobowej w 2024 roku. Dla tych 6 stacji narysuj *grouped barplot*, gdzie oś X – stacje, oś Y – liczba dni z przekroczeniem, kolor – rok (2014, 2019, 2024). Dołącz opis i interpretację obserwowanych różnic.
#
# ## Dodatkowe wymagania i sugestie
#
# - Notebook powinien zawierać *sanity checks*, np.:
#   - liczba stacji w każdym pliku,
#   - liczba dni w każdym roku,
#   - kilka przykładowych mapowań kodów stacji,
# - Wszystkie wykresy powinny mieć tytuły, legendy i krótki opis interpretacji.
# - Zachęcamy do weryfikacji kodu napisanego przez drugą osobę, gdyż ocena jest wspólna.
# - Można wykorzystać dowolne poznane biblioteki do analizy i wizualizacji danych w Pythonie.
#
# ## Kryteria oceny
#
# - Zadanie 1: 3 pkt
# - Zadanie 2: 2 pkt
# - Zadanie 3: 1.5 pkt
# - Zadanie 4: 2 pkt
# - Jakość wyjaśnień, interpretacje, opis wkładu: 1.5 pkt

# %% [markdown]
# ### 1. Wczytanie i czyszczenie danych

# %%
#edytuję ten projekt zgodnie z uwagami do mały projekt 3:
#wykonuję analizę jak wcześniej ale dla lat: 2015, 2018, 2021 i 2024 (zamiast poprzednio analizowanych 2014, 2019 i 2024)

# %%
import pandas as pd
import requests
import zipfile
import io, os

from io_clean import (
    download_gios_archive,
    usun_wiersze_opisowe,
    load_gios_metadata,
    use_station_header,
    build_old2new,
    mapuj_kolumny_z_podgladem,
    build_kod2miasto,
    dodaj_multiindex,
)

# %%
from metrics import (
    ensure_datetime,
    shift_midnight_to_prev_day,
    add_city_and_month,
    daily_station_mean,
    exceedance_days_per_year,
    select_top_bottom_stations
)

# %%
from viz import (

    plot_monthly_pm25,
    plot_pm25_heatmaps,
    plot_exceedance_bars
)

# %%
# id archiwum dla poszczególnych lat
gios_archive_url = "https://powietrze.gios.gov.pl/pjp/archives/downloadFile/"
#zmieniam lata
gios_url_ids = {2015: '236', 2018: '603', 2021: '486', 2024: '582'}
gios_pm25_file = {2015: '2015_PM25_1g.xlsx', 2018: '2018_PM25_1g.xlsx', 2021: '2021_PM25_1g.xlsx', 2024: '2024_PM25_1g.xlsx'}
meta_path = "Metadane oraz kody stacji i stanowisk pomiarowych.xlsx"
dfmeta = load_gios_metadata(meta_path)

# Przykladowe użycie
#df2024 = download_gios_archive(2024, gios_url_ids[2024], gios_pm25_file[2024])

# %%
#zmiana zalecana przez prowadzącego
lata = [2015, 2018, 2021, 2024]

datasets = {}
for rok in lata:
    datasets[rok] = download_gios_archive(rok, gios_url_ids[rok], gios_pm25_file[rok])

datasets[2024].head(10)
# Out:
#                     0                         1                      2   \
# 0                   Nr                         1                      2
# 1           Kod stacji           DsChojnowMalMOB           DsJelGorOgin
# 2             Wskaźnik                     PM2.5                  PM2.5
# 3     Czas uśredniania                        1g                     1g
# 4            Jednostka                     ug/m3                  ug/m3
# 5       Kod stanowiska  DsChojnowMalMOB-PM2.5-1g  DsJelGorOgin-PM2.5-1g
# 6  2024-01-01 01:00:00                       NaN                   30.8
# 7  2024-01-01 02:00:00                       NaN                   30.2
# 8  2024-01-01 03:00:00                       NaN                   22.4
# 9  2024-01-01 04:00:00                       NaN                   11.2
#
#                       3                         4                      5   \
# 0                      3                         4                      5
# 1           DsKlodzSzkol           DsKudowaSzkoMOB           DsWrocAlWisn
# 2                  PM2.5                     PM2.5                  PM2.5
# 3                     1g                        1g                     1g
# 4                  ug/m3                     ug/m3                  ug/m3
# 5  DsKlodzSzkol-PM2.5-1g  DsKudowaSzkoMOB-PM2.5-1g  DsWrocAlWisn-PM2.5-1g
# 6                   53.5                       NaN                     94
# 7                   61.3                       NaN                   44.8
# 8                   56.1                       NaN                   20.2
# 9                   27.6                       NaN                   14.7
#
#                       6                      7                      8   \
# 0                      6                      7                      8
# 1           DsWrocWybCon           KpBydPlPozna           KpBydWarszaw
# 2                  PM2.5                  PM2.5                  PM2.5
# 3                     1g                     1g                     1g
# 4                  ug/m3                  ug/m3                  ug/m3
# 5  DsWrocWybCon-PM2.5-1g  KpBydPlPozna-PM2.5-1g  KpBydWarszaw-PM2.5-1g
# 6                   58.3                   28.5                  110.9
# 7                   44.8                   73.9                   39.5
# 8                   30.5                   66.5                   39.6
# 9                   18.5                   66.8                   36.2
#
#                       9   ...                     87                     88  \
# 0                      9  ...                     87                     88
# 1           KpNaklWawrzy  ...           WmElkStadion           WmOlsPuszkin
# 2                  PM2.5  ...                  PM2.5                  PM2.5
# 3                     1g  ...                     1g                     1g
# 4                  ug/m3  ...                  ug/m3                  ug/m3
# 5  KpNaklWawrzy-PM2.5-1g  ...  WmElkStadion-PM2.5-1g  WmOlsPuszkin-PM2.5-1g
# 6                   96.8  ...                   48.6                   37.4
# 7                     37  ...                   12.8                   18.8
# 8                   43.6  ...                     11                     19
# 9                   42.6  ...                     10                   18.7
#
#                       89                        90                     91  \
# 0                     89                        90                     91
# 1           WpKaliSawick           WpKoscianMayMOB           WpPoznDabrow
# 2                  PM2.5                     PM2.5                  PM2.5
# 3                     1g                        1g                     1g
# 4                  ug/m3                     ug/m3                  ug/m3
# 5  WpKaliSawick-PM2.5-1g  WpKoscianMayMOB-PM2.5-1g  WpPoznDabrow-PM2.5-1g
# 6                   69.9                      90.2                   41.3
# 7                   57.1                      55.4                   38.4
# 8                     56                      46.1                   25.8
# 9                   44.1                      26.9                   16.3
#
#                       92                        93                     94  \
# 0                     92                        93                     94
# 1           WpPoznSzwajc           ZpDabkiSztorMOB           ZpKolZolkiew
# 2                  PM2.5                     PM2.5                  PM2.5
# 3                     1g                        1g                     1g
# 4                  ug/m3                     ug/m3                  ug/m3
# 5  WpPoznSzwajc-PM2.5-1g  ZpDabkiSztorMOB-PM2.5-1g  ZpKolZolkiew-PM2.5-1g
# 6                   67.9                      26.5                   63.9
# 7                   88.7                      26.8                   33.5
# 8                   84.6                      24.9                   32.9
# 9                   75.8                      26.4                   32.6
#
#                       95                     96
# 0                     95                     96
# 1           ZpSzczAndrze           ZpSzczPilsud
# 2                  PM2.5                  PM2.5
# 3                     1g                     1g
# 4                  ug/m3                  ug/m3
# 5  ZpSzczAndrze-PM2.5-1g  ZpSzczPilsud-PM2.5-1g
# 6                   49.9                   57.6
# 7                   15.4                   24.6
# 8                   14.3                   21.7
# 9                     17                   20.1
#
# [10 rows x 97 columns]

# %%
#tutaj w tym fragmencie usuwam niepotrzebne wiersze (np. "wskaźnik")
# słownik z danymi źródłowymi (twoje DataFrame’y)

#zmienione według uwag prowadzącego

cleaned = usun_wiersze_opisowe(datasets)
cleaned[2015].head()
#odnosząc do poprzedniego: zamiast df2024_clean → używamy cleaned[2024]
# Out:
# 2015: usunięto 2 wierszy opisowych, pozostało 8761
# 2018: usunięto 5 wierszy opisowych, pozostało 8761
# 2021: usunięto 5 wierszy opisowych, pozostało 8761
# 2024: usunięto 5 wierszy opisowych, pozostało 8785
#                            0             1             2             3   \
# 0                  Kod stacji  DsJelGorOgin  DsWrocAlWisn  DsWrocWybCon
# 1         2015-01-01 01:00:00       151.112            78            50
# 2         2015-01-01 02:00:00       262.566            42       33.8244
# 3  2015-01-01 03:00:00.005000        222.83            27       28.7215
# 4  2015-01-01 04:00:00.010000       210.767            24       20.6891
#
#              4             5             6             7             8   \
# 0  KpBydPlPozna  KpBydWarszaw  KpToruDziewu  LbLubObywate  LdLodzCzerni
# 1          29.2          95.5        27.352       71.1012         59.73
# 2          27.1          86.1       78.0064       95.2582        185.92
# 3           7.9          23.8       21.1056       49.5078         54.25
# 4           7.1          15.9       16.9088       60.8468         50.15
#
#              9   ...            33            34            35            36  \
# 0  LdLodzGdansk  ...  SkMalo11List  SkPolaRuszcz  SlGliwicMewy  SlKatoKossut
# 1           NaN  ...          39.6          72.4        77.828        51.389
# 2           NaN  ...          33.6          57.2       50.0552        37.709
# 3           NaN  ...            35          41.9       52.0277        41.984
# 4           NaN  ...          34.8          36.7       49.1084        45.404
#
#              37            38            39            40            41  \
# 0  SlZlotPotLes  WmOlsPuszkin  WpKaliSawick  WpPoznPolank  ZpSzczAndr01
# 1       49.9464     44.060833          25.5       24.4768           NaN
# 2       45.6291     49.943329          32.5         29.86       81.8501
# 3       49.2093     20.688448          24.3       29.3744       25.7333
# 4        53.316     17.437717          24.4         28.34        18.624
#
#              42
# 0  ZpSzczPils02
# 1           NaN
# 2       215.379
# 3       27.7458
# 4       26.5201
#
# [5 rows x 43 columns]

# %%
#mapowanie stary kod: nowy kod w słowniku
old2new = build_old2new(dfmeta)
old2new
# Out:
# {'DsBogatMob': 'DsBogatFrancMOB',
#  'DsCzer02': 'DsCzerStraza',
#  'DsDzia01': 'DsDzialoszyn',
#  'DsDzierPilsA': 'DsDziePilsud',
#  'DsGlogWita': 'DsGlogWiStwo',
#  'DsJeleniaGoraA': 'DsJelGorOgin',
#  'DsJeleniaGoraPM': 'DsJelGorSoko',
#  'DsKlodzkoA': 'DsKlodzSzkol',
#  'DsZabkowSemi': 'DsZabkPowWar',
#  'DsPolanZdrojMOB': 'DsKudSlon',
#  'DsLegRzeczA': 'DsLegPolarna',
#  'DsNRudaSrebP': 'DsNowRudSreb',
#  'DsOlawaSemi': 'DsOlawZolnAK',
#  'DsOlesnicaPM': 'DsOlesBrzozo',
#  'DsOsieczow': 'DsOsieczow21',
#  'DsPolkKasz': 'DsPolKasztan',
#  'DsSniezka': 'DsSniezkaObs',
#  'DsSwidMob': 'DsSwidnMarciMOB',
#  'DsSwidRynek': 'DsSwidnRynek',
#  'DsSzczDZPM': 'DsSzczaKolej',
#  'DsTrzebnica': 'DsTrzebniMaj',
#  'DsWalbWysA': 'DsWalbrzWyso',
#  'DsWrocWisA': 'DsWrocAlWisn',
#  'DsWrocBartA': 'DsWrocBartni',
#  'DsWrocGrobla': 'DsWrocNaGrob',
#  'DsWrocKorzA': 'DsWrocWybCon',
#  'DsZgorzBohA': 'DsZgorBohGet',
#  'DsZlotoryjaPM': 'DsZlotoStasz',
#  'KpBrodnicaKochanowskiego': 'KpBrodKochan',
#  'KpBydgBerlinga': 'KpBydFieldor',
#  'KpBydBerling': 'KpBydFieldor',
#  'KpBydgPlPozn': 'KpBydPlPozna',
#  'KpBydgWarszawska': 'KpBydWarszaw',
#  'KpCiechoTezniowa': 'KpCiechTezni',
#  'KpAirpGrudz': 'KpGrudPilsud',
#  'KpGrudzStar': 'KpGrudSienki',
#  'KpAirpInowrMatwy': 'KpInowOsMatwMOB',
#  'KpAirpInowr': 'KpInowSolank',
#  'KpKoniczZMSP': 'KpKoniczynka',
#  'KpMogilnoNowa': 'KpMogiNowMOB',
#  'KpNakloPiotraSkargi': 'KpNaklSkargi',
#  'KpNakloNowa': 'KpNaklWawrzy',
#  'KpSolecBojowMOB': 'KpSolecRowecMOB',
#  'KpTorunDziewulsk': 'KpToruDziewu',
#  'KpTorunKaszownik': 'KpToruKaszow',
#  'KpAirpTorunIMGW': 'KpToruStorczMOB',
#  'KpAirpTorun': 'KpToruWSikor',
#  'KpAirpWieniec': 'KpWieniecZdrMOB',
#  'KpAirpWiktorowo': 'KpWiktorowoG',
#  'KpAirpWlocWod': 'KpWloclChelmMOB',
#  'KpWloclOkrzei': 'KpWloclOkrze',
#  'KpWloclSielska': 'KpWloclSiels',
#  'KpZielBoryTuch': 'KpZielBoryTu',
#  'KpZninPotockiego': 'KpZninPotock',
#  'LbBialaPOrzechowa': 'LbBiaPodOrze',
#  'LbBialySlupRPN_Auto': 'LbBiaSlupRPN',
#  'LbChelmJagWIOS': 'LbChelJagiel',
#  'LbChelPolan': 'LbChelmPolan',
#  'LbJarczew': 'LbJarczWolaM',
#  'LbKrasnikKoszarowa': 'LbKrasKoszar',
#  'LbKrasnobrodMOB': 'LbKrasnobrod',
#  'LbLublinWIOS': 'LbLubObywate',
#  'LbLublin_Sliwins_5': 'LbLubSliwins',
#  'LbNaleczowMOB': 'LbNaleczAlMa',
#  'LbNaleczow': 'LbNaleczAlMa',
#  'LbPulawyKarp': 'LbPulaKarpin',
#  'LbPulawySkowieszynska': 'LbPulaSkowie',
#  'LbRadzyPSitkowskiego': 'LbRadzPodSit',
#  'LbZamoscHrubieszowsk': 'LbZamoHrubie',
#  'LdBelchatEdward': 'LdBelchEdwar',
#  'LdBrzeziWIOSMReforma': 'LdBrzeReform',
#  'LdGajewWIOSAGajew': 'LdGajewUjWod',
#  'LdKutnoWIOSMKoscius': 'LdKutnKosciu',
#  'LdLodzWIOSACzernik': 'LdLodzCzerni',
#  'LdLodzWIOSAGdanska': 'LdLodzGdansk',
#  'LdLodzWIOSAKilinsk': 'LdLodzKilins',
#  'LdLodzWSSEMLegiono': 'LdLodzLegion',
#  'LdLodzWSSEMRudzka': 'LdLodzRudzka',
#  'LdLodzWIOSAZachodn': 'LdLodzZachod',
#  'LdLowSienkie': 'LdLowiczSien',
#  'LdOpocznWIOSMPlKosci': 'LdOpocPlKosc',
#  'LdOpocCurieSk': 'LdOpocSkCuri',
#  'LdPabianWIOSMKilinsk': 'LdPabiKilins',
#  'LdPabianWIOSAKonstan': 'LdPabiKonsta',
#  'LdParzniWIOSAParznie': 'LdParzniUjWo',
#  'LdPiotrkWIOSAKrakPrz': 'LdPioTrKraPr',
#  'LdPiotrkWIOSMSienkie': 'LdPioTrSienk',
#  'LdRadomsWIOSMRolna2': 'LdRadomsRoln',
#  'LdRadomsWIOSASokola4': 'LdRadomsSoko',
#  'LdRawaMaWIOSMNiepodl': 'LdRawaNiepod',
#  'LdSieradWSSEMGrunwal': 'LdSierGrunwa',
#  'LdSkiernWIOSMKonopni': 'LdSkierKonop',
#  'LdTomaszWIOSMSwAnton': 'LdToMaSwAnto',
#  'LdUniejTermy': 'LdUniejZamko',
#  'LdWielunWIOSMPOW': 'LdWielunPOW1',
#  'LdWieluPOW12': 'LdWielunPOW1',
#  'LdZdWolaWIOSMKrolews': 'LdZduWoKrole',
#  'LdZgierzWIOSAMielcza': 'LdZgieMielcz',
#  'LuGorzowWIOS_AUT': 'LuGorzKosGdy',
#  'LuGorzowWIOS_MAN': 'LuGorzPilsud',
#  'LuSmobytWIOS_AUT': 'LuSmolBytnic',
#  'LuSulecWIOS_MOB': 'LuSulecDudka',
#  'LuWschowWIOS_AUT': 'LuWsKaziWiel',
#  'LuZaryWIOS_AUT': 'LuZarySzyman',
#  'LuZgoraWIOS_AUT': 'LuZielKrotka',
#  'MpBochniWIOSKBar0106': 'MpBochKonfed',
#  'MpBukownWIOSKole1206': 'MpBukowKolejMOB',
#  'MpGorlicWIOSKras0511': 'MpGorlKrasin',
#  'MpKetyWIOSWysp1304': 'MpKetyWyspiaMOB',
#  'MpKrakowWIOSAKra6117': 'MpKrakAlKras',
#  'MpKrakowWIOSBuja6119': 'MpKrakBujaka',
#  'MpKrakowWIOSBulw6118': 'MpKrakBulwar',
#  'MpKrakDietla': 'MpKrakKamien',
#  'MpLimanoWIOSMBBo0706': 'MpLimanoBoleMOB',
#  'MpMyslenWIOSRyne0907': 'MpMysleRynekMOB',
#  'MpWielicWIOSNiep1904': 'MpNiepo3Maja',
#  'MpNSaczWIOSNadb6205': 'MpNoSaczNadb',
#  'MpOlkuszWIOSNull1205': 'MpOlkuFrNull',
#  'MpSkawinWIOSOsie0606': 'MpSkawOsOgro',
#  'MpSlomniWIOSWoln0611': 'MpSlomWolnosMOB',
#  'MpSuchaBWIOSSemi1513': 'MpSuchSemika',
#  'MpSzarowWIOS1909': 'MpSzarowSpok',
#  'MpSzczawWIOSSzal1116': 'MpSzczawJanaMOB',
#  'MpSzymbaWIOS0507': 'MpSzymbaGorl',
#  'MpTarnowWIOSBitw6304': 'MpTarBitStud',
#  'MpTrzebiWIOSZWM0305': 'MpTrzebOsZWM',
#  'MpTuchowWIOSSzop1602': 'MpTuchChopin',
#  'MpZakopaWIOSRown1701': 'MpZakopaSien',
#  'MzBelskIGFPAN': 'MzBelsIGFPAN',
#  'MzKonJezMos': 'MzKonJezWieMOB',
#  'MzLegionZegIMGW': 'MzLegZegrzyn',
#  'MzMlawaOrdona': 'MzMlawOrdona',
#  'MzOstrolHallera': 'MzOstroHalle',
#  'MzOtwockBrzoz': 'MzOtwoBrzozo',
#  'MzPiastowPulask': 'MzPiasPulask',
#  'MzPlockPKN': 'MzPlocKroJad',
#  'MzPlockReja': 'MzPlocMiReja',
#  'MzRadomCz': 'MzRad25Czerw',
#  'MzRadomHallera': 'MzRadHallera',
#  'MzRadomTochter': 'MzRadTochter',
#  'MzSiedlceKonar': 'MzSiedKonars',
#  'MzSierWiosny': 'MzSierWiosnyMOB',
#  'MzWarszAKrzywon': 'MzWarAKrzywo',
#  'MzWarNiepodKom': 'MzWarAlNiepo',
#  'MzWarTarKondra': 'MzWarKondrat',
#  'MzWarszMarsz': 'MzWarMarszal',
#  'MzWarPodIMGW': 'MzWarPodlesn',
#  'MzWarszPorajow': 'MzWarPorajow',
#  'MzWarszPuszSolska': 'MzWarPuszSol',
#  'MzWarszBielany': 'MzWarTolstoj',
#  'MzWarszUrsynow': 'MzWarWokalna',
#  'MzZyrardRoosevel': 'MzZyraRoosev',
#  'OpGlub1pyl': 'OpGlubKochan',
#  'OpKkozle1a': 'OpKKozBSmial',
#  'OpKlucz2pyl': 'OpKluczMicki',
#  'OpKrap3MajaMOB': 'OpKrap3Maja',
#  'OpNysa3pyl': 'OpNysaRodzie',
#  'OpOlesno4a': 'OpOlesSlowac',
#  'OpOpole3a': 'OpOpoleMinor',
#  'OpOpole4pyl': 'OpOpoleOsAKr',
#  'OpStrzOpWysz': 'OpStrzOpWyszMOB',
#  'OpZdze2a': 'OpZdziePiast',
#  'PdAugustowUm': 'PdAugustowUz',
#  'PdBialyPodmiejska': 'PdBialPulPie',
#  'PdBialWaszyn': 'PdBialUpalna',
#  'PdBialyWarszawska': 'PdBialWarsza',
#  'PdBialyMiejska': 'PdBialWaszyn',
#  'PdBorsuWiejska': 'PdBorsukowiz',
#  'PdLomzaSikorskiego': 'PdLomSikorsk',
#  'PdSuwPulaskp': 'PdSuwPulask2',
#  'PkDebicaWIOSGrottgera': 'PkDebiGrottg',
#  'PkJarosWIOSPWSTE': 'PkJarosPruch',
#  'PkJasloWIOSSikorskiego': 'PkJasloSikor',
#  'PkKrempnaWIOSMPN': 'PkKrempnaMPN',
#  'PkKrosnoWIOSKletowki': 'PkKrosKletow',
#  'PkMielecWIOSSolskiego': 'PkMielSolski',
#  'PkMielWIOSZarzStr': 'PkMielZaStre',
#  'PkNiskoWIOSSzklar': 'PkNiskoSzkla',
#  'PkPrzemyslWIOSGrunw': 'PkPrzemGrunw',
#  'PkRzeszWIOSNoweMiasto': 'PkRzeszRejta',
#  'PkSanokWIOSSadowa': 'PkSanoSadowa',
#  'PkTarnobWIOSDabrow': 'PkTarnDabrow',
#  'PmChojnMOB': 'PmChojPlEmsdMOB',
#  'Pm.D': 'PmGac',
#  'Pm.00.s481m': 'PmGdaGleboka',
#  'Pm.a02a': 'PmGdaKacze02',
#  'Pm.aw08m': 'PmGdaLeczk81',
#  'Pm.a08a': 'PmGdaLeczkow',
#  'PmGdaLeczk08': 'PmGdaLeczkow',
#  'PmGdaLecz08m': 'PmGdaLeczkow',
#  'Pm.a05a': 'PmGdaOstrz05',
#  'Pm.a01a': 'PmGdaPowWars',
#  'PmGdaPoWie01': 'PmGdaPowWars',
#  'Pm.01w.02m': 'PmGdaPowWiel',
#  'Pm.a03a': 'PmGdaWyzwole',
#  'PmGdaWyzwo03': 'PmGdaWyzwole',
#  'Pm.00.w237m': 'PmGdyJozBema',
#  'Pm.a04a': 'PmGdyPorebsk',
#  'PmGdyPoreb04': 'PmGdyPorebsk',
#  'Pm.a09aN': 'PmGdySzafran',
#  'PmGdySzaf09N': 'PmGdySzafran',
#  'Pm.a10a': 'PmGdyWendy10',
#  'Pm05KARTw01m': 'PmKartWejher',
#  'Pm.AM12.a': 'PmKosTargowa',
#  'PmKosTargo12': 'PmKosTargowa',
#  'Pm.Kwidz.Sport.m': 'PmKwiSportow',
#  'Pm08LEBAiEMEPa': 'PmLebaRabka1',
#  'PmLebaRabkaE': 'PmLebaRabka1',
#  'Pm.AM16.a': 'PmLebMalczew',
#  'PmLebMalcz16': 'PmLebMalczew',
#  'Pm.AM17.a': 'PmLinieKosci',
#  'PmLinieKos17': 'PmLinieKosci',
#  'Pm.AM15.a': 'PmMalMickiew',
#  'PmMalMicki15': 'PmMalMickiew',
#  'Pm.63.wDSAa': 'PmSlupKniazi',
#  'Pm.63.wDSPm': 'PmSlupOrzesz',
#  'Pm.a06a': 'PmSopBitPl06',
#  'Pm.polpharma.01.a': 'PmStaGdaLubi',
#  'Pm.a07a': 'PmTczeTarg07',
#  'Pm.15.s129m': 'PmWejhPlWejh',
#  'Pm11WLADw07m': 'PmWladywHallera',
#  'SkBuskoWios2': 'SkBuskRokosz',
#  'SkKielJagielWios': 'SkKielJagiel',
#  'SkKielKusoc': 'SkKielKusoci',
#  'SkMalogCemen3': 'SkMalo11List',
#  'SkNowinyCemen2': 'SkNowiParkow',
#  'SkOpatPartyzMOB': 'SkOpatPartyz',
#  'SkOzarowOsWz52': 'SkOzarOsWzgo',
#  'SkPolanRuszcz': 'SkPolaRuszcz',
#  'SkSolecZdrojMOB': 'SkSolecZdroj',
#  'SkStaracZlota2': 'SkStaraZlota',
#  'SkSwKrzyzZM': 'SkSwietKrzyz',
#  'SkPolanTrzc': 'SkTrzciOsiek',
#  'SlBielbBiel_kossa': 'SlBielKossak',
#  'SlBielbBiel_stern': 'SlBielSterni',
#  'SlCieszCies_13mic': 'SlCiesMickie',
#  'SlCzestCzes_arkr1': 'SlCzestoArmK',
#  'SlCzestCzes_baczy': 'SlCzestoBacz',
#  'SlCzestCzes_zana6': 'SlCzestoZana',
#  'SlDabroDabr_1000L': 'SlDabroTysia',
#  'SlDabro1000L': 'SlDabroTysia',
#  'SlGliwiGliw_mewy': 'SlGliwicMewy',
#  'SlGodowWodz_wodzi': 'SlGodGliniki',
#  'SlKatowKato_kossu': 'SlKatoKossut',
#  'SlKatowKato_aleja': 'SlKatoPlebA4',
#  'SlKnuroKnu1_gliwi': 'SlKnurJedNar',
#  'SlLubliLubl_piask': 'SlLublPiasko',
#  'SlMyszkMysz_myszk': 'SlMyszMiedzi',
#  'SlPszczPszc_boged': 'SlPszczBoged',
#  'SlRybniRybn_borki': 'SlRybniBorki',
#  'SlSosnoSosn_lubel': 'SlSosnoLubel',
#  'SlTarnoTarn_litew': 'SlTarnoLitew',
#  'SlTychyTych_tolst': 'SlTychyTolst',
#  'SlUstroCies_sana7': 'SlUstronSana',
#  'SlWodziWodz_galcz': 'SlWodzGalczy',
#  'SlZabSkloCu2': 'SlZabSkloCu2',
#  'SlZabrzZabr_sklod': 'SlZabSkloCur',
#  'SlZawieZawi_zawie': 'SlZawSkloCur',
#  'SlZlotyJano_lesni': 'SlZlotPotLes',
#  'SlZorySikors': 'SlZorySikor2',
#  'SlZoryzZory_sikor': 'SlZorySikors',
#  'SlZywieZywi_koper': 'SlZywieKoper',
#  'SlZywieZywi_slowa': 'SlZywieSlowa',
#  'WmElblagWIOS_Bazynsk': 'WmElbBazynsk',
#  'WmGoldapWIOS_Jacwies': 'WmGoldJacwie',
#  'WmIlawaAnd': 'WmIlawAnders',
#  'WmMragowWIOS_Parkowa': 'WmMragParkow',
#  'WmNidzicaWIOS_Traugut': 'WmNiTraugutt',
#  'WmOlsztyWIOS_Puszkin': 'WmOlsPuszkin',
#  'WmOstrodWIOS_Chrobre': 'WmOstrChrobr',
#  'WmPuszcz_IOS_Borecka': 'WmPuszczaBor',
#  'WpWKP011/10': 'WpBoroDrapal',
#  'WpGnieznoPM10/11': 'WpGniePaczko',
#  'WpWKPKalisz007/10': 'WpKaliSawick',
#  'WpTarPodZach': 'WpKepnoSport',
#  'WpKonin311009D009102': 'WpKoniWyszyn',
#  'WpLesznoPM10/11': 'WpLeszKiepur',
#  'WpLeszKiepur': 'WpLesznPrusa',
#  'WpNowyTomyslPM10/11': 'WpNoTomSzpit',
#  'WpOstrowWlkpPM10': 'WpOstWieWyso',
#  'WpWKP004': 'WpPiaskiKrzy',
#  'WpPila5710111': 'WpPilaKusoci',
#  'WpPleszewPM10/14': 'WpPleszAlMic',
#  'WpWKP002': 'WpPoznDabrow',
#  'WpWKP001': 'WpPoznPolank',
#  'WpPoznanPOSIRPM10/11': 'WpPoznSpycha',
#  'WpPoznChwial': 'WpPoznSpycha',
#  'WpPoznanSzymanowskiego17': 'WpPoznSzyman',
#  'WpSzamotuMOB': 'WpSzamotKollMOB',
#  'WpTarnowoPodgornePM10/10': 'WpTarPodZach',
#  'WpWagrowiecPM10/10': 'WpWagrowLipo',
#  'ZpKoszalin005': 'ZpKoszArKraj',
#  'ZpKoszalin006': 'ZpKoszSpasow',
#  'ZpMysMysliborz007': 'ZpMyslZaBram',
#  'ZpSzczecin001': 'ZpSzczAndrze',
#  'ZpSzczAndr01': 'ZpSzczAndrze',
#  'ZpSzcSzczecinek008': 'ZpSzczec1Maj',
#  'ZpSzcSzczecinek010': 'ZpSzczecPrze',
#  'ZpSzczecin004': 'ZpSzczLacz04',
#  'ZpSzczecin002': 'ZpSzczPilsud',
#  'ZpSzczPils02': 'ZpSzczPilsud',
#  'ZpGryfWiduchowa003': 'ZpWiduBulRyb'}

# %%
#Zamiana wiersza "Kod stacji" na nagłówek i dodanie kolumny 'Data', żeby ujednolicić format
#potem zmapuję stare kody stacji na nowe zgodnie z metadanymi (słownik powyżej)

hdr = {}
for rok in lata:
    hdr[rok] = use_station_header(cleaned[rok])
hdr[2015]
# Out:
#                             Data DsJelGorOgin DsWrocAlWisn DsWrocWybCon  \
# 0            2015-01-01 01:00:00      151.112           78           50
# 1            2015-01-01 02:00:00      262.566           42      33.8244
# 2     2015-01-01 03:00:00.005000       222.83           27      28.7215
# 3     2015-01-01 04:00:00.010000      210.767           24      20.6891
# 4     2015-01-01 05:00:00.015000      191.211           22      22.5335
# ...                          ...          ...          ...          ...
# 8755  2015-12-31 20:00:43.770000      13.7734      29.2072      24.4965
# 8756  2015-12-31 21:00:43.775000      20.8195      36.8677      39.4025
# 8757  2015-12-31 22:00:43.780000      11.7978       61.041      52.4493
# 8758  2015-12-31 23:00:43.785000      16.6281      67.5414      59.3307
# 8759  2016-01-01 00:00:43.790000      16.1148      74.7532      91.8786
#
#      KpBydPlPozna KpBydWarszaw KpToruDziewu LbLubObywate LdLodzCzerni  \
# 0            29.2         95.5       27.352      71.1012        59.73
# 1            27.1         86.1      78.0064      95.2582       185.92
# 2             7.9         23.8      21.1056      49.5078        54.25
# 3             7.1         15.9      16.9088      60.8468        50.15
# 4             9.2           15      16.8112      49.3106        39.17
# ...           ...          ...          ...          ...          ...
# 8755          NaN         76.2          NaN      62.7976           31
# 8756         55.4         66.9          NaN       105.59           46
# 8757          NaN         69.2          NaN     232.0938           46
# 8758         71.1         65.5          NaN     203.4012           49
# 8759         68.9         62.2          NaN     205.5704           50
#
#      LdLodzGdansk  ... SkMalo11List SkPolaRuszcz SlGliwicMewy SlKatoKossut  \
# 0             NaN  ...         39.6         72.4       77.828       51.389
# 1             NaN  ...         33.6         57.2      50.0552       37.709
# 2             NaN  ...           35         41.9      52.0277       41.984
# 3             NaN  ...         34.8         36.7      49.1084       45.404
# 4             NaN  ...         35.8           36      44.0588       36.854
# ...           ...  ...          ...          ...          ...          ...
# 8755           57  ...           28           59      205.944       158.52
# 8756           60  ...         36.8         57.4      218.516      143.729
# 8757           58  ...         33.3         73.8      169.238      131.673
# 8758           57  ...         38.2         70.9      115.688      119.533
# 8759           59  ...         41.6        113.2      92.8687      133.811
#
#      SlZlotPotLes WmOlsPuszkin WpKaliSawick WpPoznPolank ZpSzczAndr01  \
# 0         49.9464    44.060833         25.5      24.4768          NaN
# 1         45.6291    49.943329         32.5        29.86      81.8501
# 2         49.2093    20.688448         24.3      29.3744      25.7333
# 3          53.316    17.437717         24.4        28.34       18.624
# 4         51.5259    15.532262           25      25.2286      17.6545
# ...           ...          ...          ...          ...          ...
# 8755      42.9334    34.510277        75.05      36.3858      30.6219
# 8756           45       35.861      62.8491        40.31      50.1254
# 8757      63.9197    36.309914      70.6655       43.079      38.0602
# 8758      56.2223    38.686676      80.2882        52.32      193.129
# 8759      51.6207    40.265392      87.1236      55.9351      76.8539
#
#      ZpSzczPils02
# 0             NaN
# 1         215.379
# 2         27.7458
# 3         26.5201
# 4         31.0393
# ...           ...
# 8755      30.2969
# 8756      27.2376
# 8757      28.3642
# 8758      34.8272
# 8759      29.8422
#
# [8760 rows x 43 columns]

# %%
kod2miasto = build_kod2miasto(dfmeta)
kod2miasto
# Out:
# {'DsBialka': 'Białka',
#  'DsBielGrot': 'Bielawa',
#  'DsBogatFrancMOB': 'Bogatynia',
#  'DsBogChop': 'Bogatynia',
#  'DsBogZatonieMob': 'Bogatynia',
#  'DsBoleslaMOB': 'Bolesławiec',
#  'DsBrzegGlog': 'Brzeg Głogowski',
#  'DsChojnowKil': 'Chojnów',
#  'DsChojnowMalMOB': 'Chojnów',
#  'DsCzar07': 'Czarna Góra',
#  'DsCzerStraza': 'Czerniawa',
#  'DsCzLasMob': 'Czarny Las',
#  'DsDusznikMOB': 'Duszniki-Zdrój',
#  'DsDuszZiel': 'Duszniki-Zdrój',
#  'DsDzialoszyn': 'Działoszyn',
#  'DsDziePilsud': 'Dzierżoniów',
#  'DsDzierKras': 'Dzierżoniów',
#  'DsGlogMob': 'Głogów',
#  'DsGlogNorw': 'Głogów',
#  'DsGlogNorwArch': 'Głogów',
#  'DsGlogOrzech': 'Głogów',
#  'DsGlogowko': 'Głogówko',
#  'DsGlogSikor': 'Głogów',
#  'DsGlogWiStwo': 'Głogów',
#  'DsGrodziec': 'Grodziec Mały',
#  'DsJasnaSport': 'Jasna Góra',
#  'DsJawDmow': 'Jawor',
#  'DsJaworMOB': 'Jawor',
#  'DsJedlinaZdrMOB': 'Jedlina-Zdrój',
#  'DsJedlZdroj': 'Jedlina-Zdrój',
#  'DsJelGorOgin': 'Jelenia Góra',
#  'DsJelGorSoko': 'Jelenia Góra',
#  'DsJelw05': 'Jeleniów',
#  'DsJgCiep': 'Jelenia Góra',
#  'DsJgCiepA': 'Jelenia Góra',
#  'DsJgGrottgeraPM': 'Jelenia Góra',
#  'DsJgGrottgeraPMArch': 'Jelenia Góra',
#  'DsJgScieg': 'Jelenia Góra',
#  'DsJgWoln': 'Jelenia Góra',
#  'DsJgZabob': 'Jelenia Góra',
#  'DsKalinowka': 'Kalinowka',
#  'DsKamGoraMOB': 'Kamienna Góra',
#  'DsKawice': 'Kawice',
#  'DsKgMob': 'Kamienna Góra',
#  'DsKgSien': 'Kamienna Góra',
#  'DsKlodzOkrz': 'Kłodzko',
#  'DsKlodzSzkol': 'Kłodzko',
#  'DsKobierz': 'Kobierzyce',
#  'DsKostrzaMOB': 'Kostrza',
#  'DsKowMaj': 'Kowary',
#  'DsKozDoly': 'Kozie Doły',
#  'DsKromolin': 'Kromolin',
#  'DsKudowaMOB': 'Kudowa-Zdrój',
#  'DsKudowaSzkoMOB': 'Kudowa-Zdrój',
#  'DsKudSlon': 'Kudowa-Zdrój',
#  'DsLadekMOB': 'Lądek-Zdrój',
#  'DsLadekWol': 'Lądek-Zdrój',
#  'DsLegAlRzecz': 'Legnica',
#  'DsLegIwasz': 'Legnica',
#  'DsLegJaworz': 'Legnica',
#  'DsLegKsiez': 'Legnica',
#  'DsLegMick': 'Legnica',
#  'DsLegPolarna': 'Legnica',
#  'DsLegPoraz': 'Legnica',
#  'DsLegRzecz': 'Legnica',
#  'DsLegRzeczPM': 'Legnica',
#  'DsLegSmok': 'Legnica',
#  'DsLegZlotor': 'Legnica',
#  'DsLesnaRyn': 'Leśna',
#  'DsLubanMieszMOB': 'Lubań',
#  'DsLubanMOB': 'Lubań',
#  'DsLubanRyn': 'Lubań',
#  'DsLubanZaw': 'Lubań',
#  'DsLubinMaj': 'Lubin',
#  'DsLubinMob': 'Lubin',
#  'DsLubinSowia': 'Lubin',
#  'DsLubiWierzb': 'Lubin',
#  'DsLwowekPart': 'Lwówek Śląski',
#  'DsLwowekSlasMOB': 'Lwówek Śląski',
#  'DsMiliczMOB': 'Milicz',
#  'DsNowRudJezi': 'Nowa Ruda',
#  'DsNowRudSreb': 'Nowa Ruda',
#  'DsNRudaPil': 'Nowa Ruda',
#  'DsNRudaSlupPM': 'Nowa Ruda - Słupiec',
#  'DsNRudaSrebA': 'Nowa Ruda',
#  'DsNRudaSrebPArch': 'Nowa Ruda',
#  'DsOla3Maj': 'Oława',
#  'DsOlawZolnAK': 'Oława',
#  'DsOlesBrzozo': 'Oleśnica',
#  'DsOlesnicaPM-Arch': 'Oleśnica',
#  'DsOlesRyn': 'Oleśnica',
#  'DsOsieczow21': 'Osieczów',
#  'DsPolanPark': 'Polanica-Zdrój',
#  'DsPolanSportMOB': 'Polanica-Zdrój',
#  'DsPolanZdrojMOB': 'Polanica-Zdrój',
#  'DsPolKasztan': 'Polkowice',
#  'DsPolkDabr': 'Polkowice',
#  'DsPrzerzZdr': 'Przerzeczyn-Zdrój',
#  'DsRadomierz': 'Radomierzyce',
#  'DsRudna': 'Rudna',
#  'DsRudnaWit': 'Rudna',
#  'DsSlone': 'Słone',
#  'DsSnie04': 'Śnieżne Kotły',
#  'DsSniezkaObs': 'Karpacz',
#  'DsSobczyce': 'Sobczyce',
#  'DsSoko08': 'Sokolec',
#  'DsSpal06': 'Spalona',
#  'DsSrodaSlMOB': 'Środa Śląska',
#  'DsStrzegomMOB': 'Strzegom',
#  'DsStrzMob': 'Strzelin',
#  'DsSwidnFolwa': 'Świdnica',
#  'DsSwidnMarciMOB': 'Świdnica',
#  'DsSwidnRynek': 'Świdnica',
#  'DsSwidRynekArch': 'Świdnica',
#  'DsSwidWalb': 'Świdnica',
#  'DsSzczaKolej': 'Szczawno-Zdrój',
#  'DsSzczAzalMob': 'Szczawno-Zdrój',
#  'DsSzczKopPM': 'Szczawno-Zdrój',
#  'DsSzczMagMob': 'Szczawno-Zdrój',
#  'DsSzczOgr': 'Szczawno-Zdrój',
#  'DsSzczRat': 'Szczawno-Zdrój',
#  'DsSzklarkiMob': 'Szklarki',
#  'DsSzkPor1MajMOB': 'Szklarska Poręba',
#  'DsTarnowek': 'Tarnowek',
#  'DsTrzebBoch': 'Trzebnica',
#  'DsTrzebLes': 'Trzebnica',
#  'DsTrzebMob': 'Trzebnica',
#  'DsTrzebniMaj': 'Trzebnica',
#  'DsWalbBator': 'Wałbrzych',
#  'DsWalbGrodz': 'Wałbrzych',
#  'DsWalbJord': 'Wałbrzych',
#  'DsWalbKost': 'Wałbrzych',
#  'DsWalbrzWyso': 'Wałbrzych',
#  'DsWalbWysPArch': 'Wałbrzych',
#  'DsWitk09': 'Witków',
#  'DsWitka': 'Witka',
#  'DsWlen03': 'Wleń',
#  'DsWrocAlWisn': 'Wrocław',
#  'DsWrocBartni': 'Wrocław',
#  'DsWrocGrun': 'Wrocław',
#  'DsWrocKorzPMArch': 'Wrocław',
#  'DsWrocKrom': 'Wrocław',
#  'DsWrocNaGrob': 'Wrocław',
#  'DsWrocOlsz': 'Wrocław',
#  'DsWrocOpor': 'Wrocław',
#  'DsWrocOrzech': 'Wrocław',
#  'DsWrocOrzechArch': 'Wrocław',
#  'DsWrocPret': 'Wrocław',
#  'DsWrocSklad': 'Wrocław',
#  'DsWrocTech': 'Wrocław',
#  'DsWrocUkr': 'Wrocław',
#  'DsWrocWie': 'Wrocław',
#  'DsWrocWybCon': 'Wrocław',
#  'DsWyszkow': 'Wyszków',
#  'DsZabkKlodz': 'Ząbkowice Śląskie',
#  'DsZabkPowWar': 'Ząbkowice Śląskie',
#  'DsZameczno': 'Zameczno',
#  'DsZgorBohGet': 'Zgorzelec',
#  'DsZgorzMar': 'Zgorzelec',
#  'DsZgorzOrz': 'Zgorzelec',
#  'DsZgorzWar': 'Zgorzelec',
#  'DsZlotKosc': 'Złotoryja',
#  'DsZlotoryjaPMArch': 'Złotoryja',
#  'DsZlotoStasz': 'Złotoryja',
#  'DsZukowice': 'Żukowice',
#  'KpAirpKoluda': 'Kołuda Wielka',
#  'KpBrodKochan': 'Brodnica',
#  'KpBrodnZwirki': 'Brodnica',
#  'KpBydFieldor': 'Bydgoszcz',
#  'KpBydgATRKalisk': 'Bydgoszcz',
#  'KpBydgBlota': 'Białe Błota',
#  'KpBydgChemEC': 'Bydgoszcz',
#  'KpBydgCO': 'Bydgoszcz',
#  'KpBydgMorska': 'Bydgoszcz',
#  'KpBydgUjejskiego': 'Bydgoszcz',
#  'KpBydgWPola': 'Bydgoszcz',
#  'KpBydgWzgWolnosci': 'Bydgoszcz',
#  'KpBydgZachemHutn': 'Bydgoszcz',
#  'KpBydgZachemWojska': 'Bydgoszcz',
#  'KpBydJezdzie': 'Bydgoszcz',
#  'KpBydPlPozna': 'Bydgoszcz',
#  'KpBydWarszaw': 'Bydgoszcz',
#  'KpChelmLunawMOB': 'Chełmno',
#  'KpChelmnLunawska': 'Chełmno',
#  'KpCiechTezni': 'Ciechocinek',
#  'KpDAFAleksandrowK': 'Aleksandrów Kujawski',
#  'KpDAFBrzescK': 'Brześć Kujawski',
#  'KpDAFChelmza': 'Chełmża',
#  'KpDAFChodecz': 'Chodecz',
#  'KpDAFDobrzynUM': 'Dobrzyń nad Wisłą',
#  'KpDAFGolub': 'Golub-Dobrzyń',
#  'KpDAFIzbica': 'Izbica Kujawska',
#  'KpDAFLasin': 'Łasin',
#  'KpDAFMarusza': 'Grudziądz',
#  'KpDAFNieszawa': 'Nieszawa',
#  'KpDAFRadziejowRPGK': 'Radziejów',
#  'KpDAFRadzyn': 'Radzyń Chełmiński',
#  'KpDAFRypinKOMES': 'Rypin',
#  'KpGrudPilsud': 'Grudziądz',
#  'KpGrudSienki': 'Grudziądz',
#  'KpGrudzIkara': 'Grudziądz',
#  'KpGrudzKosynierow': 'Grudziądz',
#  'KpInowOsMatwMOB': 'Inowrocław',
#  'KpInowrKleeberga': 'Inowrocław',
#  'KpInowrMatewska': 'Inowrocław',
#  'KpInowrPlacKlaszt': 'Inowrocław',
#  'KpInowrPoznanska': 'Inowrocław',
#  'KpInowrSolan': 'Inowrocław',
#  'KpInowrSolankowa': 'Inowrocław',
#  'KpInowSolank': 'Inowrocław',
#  'KpKoniczynka': 'Koniczynka',
#  'KpKruszwicamob': 'Kruszwica',
#  'KpKruszynLotnisko': 'Kruszyn',
#  'KpMogilKosciuszki': 'Mogilno',
#  'KpMogiNowMOB': 'Mogilno',
#  'KpNakloSkargi': 'Nakło nad Notecią',
#  'KpNaklSkargi': 'Nakło nad Notecią',
#  'KpNaklWawrzy': 'Nakło nad Notecią',
#  'KpNwiesNaftobazy': 'Nowa Wies Wielka',
#  'KpPiech': 'Piechcin',
#  'KpPrzysRCRRiOW': 'Przysiek',
#  'KpSadlog': 'Sadłogoszcz',
#  'KpSepolno': 'Sępólno Krajeńskie',
#  'KpSolecRowecMOB': 'Solec Kujawski',
#  'KpSwiecGruczno': 'Górne Gruczno',
#  'KpSwiecGruczno2': 'Górne Gruczno',
#  'KpSwiecJPawlMOB': 'Świecie',
#  'KpSwiecKolejowa': 'Świecie',
#  'KpSwiecPrzechowo': 'Świecie Przechowo',
#  'KpSwiecSadowa': 'Świecie',
#  'KpToruDziewu': 'Toruń',
#  'KpToruKaszow': 'Toruń',
#  'KpTorunGagarina': 'Toruń',
#  'KpTorunKonstytucji': 'Toruń',
#  'KpTorunKopernika': 'Toruń',
#  'KpTorunLotnisko': 'Toruń',
#  'KpTorunOPSIS': 'Toruń',
#  'KpTorunPoznanska': 'Toruń',
#  'KpTorunSzpMiejski': 'Toruń',
#  'KpToruStorczMOB': 'Toruń',
#  'KpToruWSikor': 'Toruń',
#  'KpTuchPiast': 'Tuchola',
#  'KpTuchPiastowska': 'Tuchola',
#  'KpWabrzMuzeum': 'Wąbrzeźno',
#  'KpWabrzstmob': 'Wąbrzeźno',
#  'KpWieniecZdrMOB': 'Wieniec-Zdrój',
#  'KpWieniZdroj': 'Wieniec-Zdrój',
#  'KpWienSanatorium': 'Wieniec-Zdrój',
#  'KpWiktorowoG': 'Wiktorowo',
#  'KpWloclChelmMOB': 'Włocławek',
#  'KpWloclGnia2': 'Włocławek',
#  'KpWloclGniaz': 'Włocławek',
#  'KpWloclKalis': 'Włocławek',
#  'KpWloclKilinskiego': 'Włocławek',
#  'KpWloclLady': 'Włocławek',
#  'KpWloclMalinowa': 'Włocławek',
#  'KpWloclOkrze': 'Włocławek',
#  'KpWloclOpsis': 'Włocławek',
#  'KpWloclPlocka': 'Włocławek',
#  'KpWloclSiels': 'Włocławek',
#  'KpWloclWSHE': 'Włocławek',
#  'KpWlocZytnia': 'Włocławek',
#  'KpWolice': 'Wolice',
#  'KpZielBoryTu': 'Zielonka',
#  'KpZninBrowarowa': 'Żnin',
#  'KpZninPotock': 'Żnin',
#  'LbBialaPKopernika': 'Biała Podlaska',
#  'LbBialaPPl.TrzechKrzyzy': 'Biała Podlaska',
#  'LbBialySlupRPN': 'Biały Słup',
#  'LbBiaPodOrze': 'Biała Podlaska',
#  'LbBiaSlupRPN': 'Biały Słup',
#  'LbBilgorajWSSE': 'Biłgoraj',
#  'LbChelJagiel': 'Chełm',
#  'LbChelmPolan': 'Chełm',
#  'LbChelmPolWSSE': 'Chełm',
#  'LbChelmSzpWSSE': 'Chełm',
#  'LbDorohWIOS': 'Dorohusk',
#  'LbFlorianRPN': 'Florianka',
#  'LbHrubieszowWIOS': 'Hrubieszów',
#  'LbHrubieszowWSSE': 'Hrubieszów',
#  'LbJanowLubOkMOB': 'Janów Lubelski',
#  'LbJarczWolaM': 'Jarczew',
#  'LbKra-awWSSE': 'Krasnystaw',
#  'LbKrasKoszar': 'Kraśnik',
#  'LbKrasnikSpoldziel': 'Kraśnik',
#  'LbKrasnobrod': 'Krasnobród',
#  'LbKrasnobrodWSSELel': 'Krasnobród',
#  'LbLeczna1000Lecia': 'Łęczna',
#  'LbLublin_Chmielna': 'Lublin',
#  'LbLublin_Krasn': 'Lublin',
#  'LbLublinMaszynowa': 'Lublin',
#  'LbLublinNadrzecz': 'Lublin',
#  'LbLublinObywat_13': 'Lublin',
#  'LbLublinOgrod': 'Lublin',
#  'LbLublinPiel': 'Lublin',
#  'LbLublinSpokojna': 'Lublin',
#  'LbLubObywate': 'Lublin',
#  'LbLubSliwins': 'Lublin',
#  'LbLukBulNiepMOB': 'Łuków',
#  'LbLukowBrowarna': 'Łuków',
#  'LbLukowSpoldzielcza': 'Łuków',
#  'LbMiedzPModrzewiowa': 'Międzyrzec Podlaski',
#  'LBMiedzPStaromiejska': 'Międzyrzec Podlaski',
#  'LbNaleczAlMa': 'Nałęczów',
#  'LbNaleczowKasztan': 'Nałęczów',
#  'LbPulaKarpin': 'Puławy',
#  'LbPulaSkowie': 'Puławy',
#  'LbPulawyLubelska': 'Puławy',
#  'LbRadzPodSit': 'Radzyń Podlaski',
#  'LbRadzyPPocztowa': 'Radzyń Podlaski',
#  'LbRejowiecFabrWIOS': 'Rejowiec Fabryczny',
#  'LbSwidnikWPolskiego': 'Świdnik',
#  'LbSwidnikWyszyns': 'Świdnik',
#  'LbSzczebPartyzantow': 'Szczebrzeszyn',
#  'LbTomaszowLubWIOS': 'Tomaszów Lubelski',
#  'LbTomaszowLubWSSE': 'Tomaszów Lubelski',
#  'LbWilczopole': 'Wilczopole',
#  'LbWlodawWSSE': 'Włodawa',
#  'LbZamoHrubie': 'Zamość',
#  'LbZamoscWSSE': 'Zamość',
#  'LdAlekslWSSEMSklodow': 'Aleksandrów Łódzki',
#  'LdBelchaWSSEMOkrzei': 'Bełchatów',
#  'LdBelchEdwar': 'Bełchatów',
#  'LdBrzeReform': 'Brzeziny',
#  'LdBrzeziWSSEMReforma': 'Brzeziny',
#  'LdGajewUjWod': 'Gajew',
#  'LdKutn1Maja7MOB': 'Kutno',
#  'LdKutnKosciu': 'Kutno',
#  'LdKutnoWIOSMWilcza': 'Kutno',
#  'LdKutnoWSSEMGrunwal': 'Kutno',
#  'LdLaskNarutoMOB': 'Łask',
#  'LdLaskWSSEMWarszaw': 'Łask',
#  'LdLodzCzerni': 'Łódź',
#  'LdLodzGdansk': 'Łódź',
#  'LdLodzJanPaw': 'Łódź',
#  'LdLodzKilins': 'Łódź',
#  'LdLodzLegion': 'Łódź',
#  'LdLodzRudzka': 'Łódź',
#  'LdLodzWIOSARubinst': 'Łódź',
#  'LdLodzWSSEMAstrona': 'Łódź',
#  'LdLodzWSSEMDeczyns': 'Łódź',
#  'LdLodzWSSEMPrzybys': 'Łódź',
#  'LdLodzWSSEMRokicin': 'Łódź',
#  'LdLodzWSSEMWici3': 'Łódź',
#  'LdLodzWSSEMWilensk': 'Łódź',
#  'LdLodzWSSEMWodna40': 'Łódź',
#  'LdLodzWSSEMZachodn': 'Łódź',
#  'LdLodzZachod': 'Łódź',
#  'LdLowiczSien': 'Łowicz',
#  'LdLowiczWSSEMSwFlori': 'Łowicz',
#  'LdOpocPlKosc': 'Opoczno',
#  'LdOpocSkCuri': 'Opoczno',
#  'LdOpocznWSSEMPlKosci': 'Opoczno',
#  'LdOzorkoWSSEMWigury1': 'Ozorków',
#  'LdPabianWSSEMNowa': 'Pabianice',
#  'LdPabiKilins': 'Pabianice',
#  'LdPabiKonsta': 'Pabianice',
#  'LdPajeczWSSEMZeromsk': 'Pajęczno',
#  'LdParzniUjWo': 'Parzniewice',
#  'LdPiotrkMZGKMkarolin': 'Piotrków Trybunalski',
#  'LdPioTrKraPr': 'Piotrków Trybunalski',
#  'LdPiotrkWIOSABelzack': 'Piotrków Trybunalski',
#  'LdPiotrkWSSEM3goMaja': 'Piotrków Trybunalski',
#  'LdPioTrSienk': 'Piotrków Trybunalski',
#  'LdRadomsFAMEGMGlinia': 'Radomsko',
#  'LdRadomsFAMEGMGolebi': 'Radomsko',
#  'LdRadomsMETALMPrzedb': 'Radomsko',
#  'LdRadomsRoln': 'Radomsko',
#  'LdRadomsSoko': 'Radomsko',
#  'LdRadomsWSSEMKomunyP': 'Radomsko',
#  'LdRadomsWSSEMZeromsk': 'Radomsko',
#  'LdRawaMaWIOSMKoscius': 'Rawa Mazowiecka',
#  'LdRawaNiepod': 'Rawa Mazowiecka',
#  'LdSieradWIOSMKoscius': 'Sieradz',
#  'LdSieradWSSEMArmiiKr': 'Sieradz',
#  'LdSieradWSSEMPOW52': 'Sieradz',
#  'LdSieraPolna': 'Sieradz',
#  'LdSierGrunwa': 'Sieradz',
#  'LdSkierKonop': 'Skierniewice',
#  'LdSkiernWIOSMJagiell': 'Skierniewice',
#  'LdSkiernWIOSMWitaStw': 'Skierniewice',
#  'LdSkiernWSSEMKoperni': 'Skierniewice',
#  'LdSkiernWSSEMReymont': 'Skierniewice',
#  'LdSkiernWSSEMWankowi': 'Skierniewice',
#  'LdToMaSwAnto': 'Tomaszów Mazowiecki',
#  'LdTomaszWSSEMSw.Anto': 'Tomaszów Mazowiecki',
#  'LdUniejZamko': 'Uniejów',
#  'LdWielunPOW1': 'Wieluń',
#  'LdWielunWSSEMPOW14': 'Wieluń',
#  'LdWielunWSSEMWojskaP': 'Wieluń',
#  'LdZduWoKrole': 'Zduńska Wola',
#  'LdZdWolaWSSEMDabrows': 'Zduńska Wola',
#  'LdZdWolaWSSEMPlWolno': 'Zduńska Wola',
#  'LdZdWolaWSSEMSzadkow': 'Zduńska Wola',
#  'LdZgieMielcz': 'Zgierz',
#  'LdZgierzWSSEMDabrows': 'Zgierz',
#  'LdZgierzWSSEMStRynek': 'Zgierz',
#  'LdZloczeWSSEMWieluns': 'Złoczew',
#  'LuDrezdeWSSE': 'Drezdenko',
#  'LuGorzKosGdy': 'Gorzów Wielkopolski',
#  'LuGorzowWSSE_1': 'Gorzów Wielkopolski',
#  'LuGorzowWSSE_5': 'Gorzów Wielkopolski',
#  'LuGorzowWSSE_6': 'Gorzów Wielkopolski',
#  'LuGorzPilsud': 'Gorzów Wielkopolski',
#  'LuGubinAnderMOB': 'Gubin',
#  'LuLubsStrzelMOB ': 'Lubsko',
#  'LuMiedzyrMOB': 'Międzyrzecz',
#  'LuMiedzyWSSE': 'Międzyrzecz',
#  'LuNowaSolKos': 'Nowa Sól',
#  'LuNowaSolMOB': 'Nowa Sól',
#  'LuNowasoWSSE': 'Nowa Sól',
#  'LuSlubWIOS_AUT': 'Słubice',
#  'LuSlubWSSE': 'Słubice',
#  'LuSmolBytnic': 'Smolary Bytnickie',
#  'LuSulecDudka': 'Sulęcin',
#  'LuSuleciWSSE': 'Sulęcin',
#  'LuSwiebodMOB': 'Świebodzin',
#  'LuSwieboWIOS_MOB': 'Świebodzin',
#  'LuSwieboWSSE': 'Świebodzin',
#  'LuWsKaziWiel': 'Wschowa',
#  'LuZaganKochaMOB': 'Żagań',
#  'LuZaganWSSE': 'Żagań',
#  'LuZarySzyman': 'Żary',
#  'LuZaryWIOS_MAN': 'Żary',
#  'LuZaryWIOS_MOB': 'Żary',
#  'LuZaryWSSE': 'Żary',
#  'LuZaryWSSE_2': 'Żary',
#  'LuZgoraWSSE_1': 'Zielona Góra',
#  'LuZielKrotka': 'Zielona Góra',
#  'LuZielWyszyn': 'Zielona Góra',
#  'MpAndrycWSSEKrak1801': 'Andrychów',
#  'MpBochKonfed': 'Bochnia',
#  'MpBochniWSSEKazi0104': 'Bochnia',
#  'MpBochniWSSEKons0105': 'Bochnia',
#  'MpBochniWSSESoln0102': 'Bochnia',
#  'MpBrzeskWIOSWiej0202': 'Brzesko',
#  'MpBrzeskWSSEGlow0201': 'Brzesko',
#  'MpBrzeszKosc': 'Brzeszcze',
#  'MpBukowKolejMOB': 'Bukowno',
#  'MpChrzanWSSEGrzy0301': 'Chrzanów',
#  'MpChrzaPlTysMOB': 'Chrzanów',
#  'MpDabrowWIOSZare0401': 'Dąbrowa Tarnowska',
#  'MpDobczSzkolMOB': 'Dobczyce',
#  'MpDobrowWSSEPils0401': 'Dąbrowa Tarnowska',
#  'MpGorlicWSSELegi0501': 'Gorlice',
#  'MpGorlKrasin': 'Gorlice',
#  'MpKalZebRyneMOB': 'Kalwaria Zebrzydowska',
#  'MpKaszowLisz': 'Kaszów',
#  'MpKetyWyspiaMOB': 'Kęty',
#  'MpKrakAlKras': 'Kraków',
#  'MpKrakBujaka': 'Kraków',
#  'MpKrakBulwar': 'Kraków',
#  'MpKrakDietla': 'Kraków',
#  'MpKrakKamien': 'Kraków',
#  'MpKrakOsPias': 'Kraków',
#  'MpKrakowWIOSPrad6115': 'Kraków',
#  'MpKrakowWSSEKapi6108': 'Kraków',
#  'MpKrakowWSSEPrad6102': 'Kraków',
#  'MpKrakowWSSERPod6113': 'Kraków',
#  'MpKrakSwoszo': 'Kraków',
#  'MpKrakTelime': 'Kraków',
#  'MpKrakWadow': 'Kraków',
#  'MpKrakZloRog': 'Kraków',
#  'MpKrynicDiet': 'Krynica-Zdrój',
#  'MpKrynicWIOSNowo1008': 'Krynica-Zdrój',
#  'MpKrynicWIOSPark1009': 'Krynica-Zdrój',
#  'MpKrynicWSSENowo1002': 'Krynica',
#  'MpKrzeszWIOSKulc0605': 'Krzeszowice',
#  'MpLimanoBoleMOB': 'Limanowa',
#  'MpMaPodhWIOSKosc1508': 'Maków Podhalański',
#  'MpMiechoWIOSKono0802': 'Miechów',
#  'MpMiechoWIOSKsSk0801': 'Miechów',
#  'MpMszanaDoln': 'Mszana Dolna',
#  'MpMuszynKity': 'Muszyna',
#  'MpMuszynKityMOB': 'Muszyna',
#  'MpMuszynLodoMOB': 'Muszyna',
#  'MpMuszynWSSERyne1001': 'Muszyna',
#  'MpMuszynZloc': 'Złockie',
#  'MpMyslenSoli': 'Myślenice',
#  'MpMyslenWIOSKazi0901': 'Myślenice',
#  'MpMyslenWIOSKosc0902': 'Myślenice',
#  'MpMyslenWIOSRyne0905': 'Myślenice',
#  'MpMyslenWIOSRyne0906': 'Myślenice',
#  'MpMysleRynekMOB': 'Myślenice',
#  'MpNiepo3Maja': 'Niepołomice',
#  'MpNiepolWIOSRyne1907': 'Niepołomice',
#  'MpNoSaczNadb': 'Nowy Sącz',
#  'MpNoSaczWSSENawo17a': 'Nowy Sącz',
#  'MpNoTargAlTy': 'Nowy Targ',
#  'MpNoTargPSlo': 'Nowy Targ',
#  'MpNoTargWSSESzaf1102': 'Nowy Targ',
#  'MpNowyTaWIOSPows1114': 'Nowy Targ',
#  'MpNSaczWIOSPija6204': 'Nowy Sącz',
#  'MpNSaczWSSETarn6202': 'Nowy Sącz',
#  'MpOlkuCegiel': 'Olkusz',
#  'MpOlkuFrNull': 'Olkusz',
#  'MpOswiecBema': 'Oświęcim',
#  'MpOswiecWIOSSnia1302': 'Oświęcim',
#  'MpOswiecWIOSSnia1304': 'Oświęcim',
#  'MpOswiecWSSEWiez1301': 'Oświęcim',
#  'MpPiwnicWSSERyne1004': 'Piwniczna',
#  'MpPiwnZdrojoMOB': 'Piwniczna',
#  'MpProszoWIOS3Maj1402': 'Proszowice',
#  'MpProszWIOSKrol1404': 'Proszowice',
#  'MpRabkaOrkan': 'Rabka-Zdrój',
#  'MpRabkaWIOSChop1113': 'Rabka-Zdrój',
#  'MpRabkaWIOSRudn1112': 'Rabka-Zdrój',
#  'MpRabkaWSSEOrka1105': 'Rabka-Zdrój',
#  'MpSkawOsOgro': 'Skawina',
#  'MpSkawStudzi': 'Skawina',
#  'MpSlomWolnosMOB': 'Słomniki',
#  'MpSuchaBWIOSHand1512': 'Sucha Beskidzka',
#  'MpSuchaNiesz': 'Sucha Beskidzka',
#  'MpSuchaWIOSBeni1501': 'Sucha Beskidzka',
#  'MpSuchaWIOSMick1502': 'Sucha Beskidzka',
#  'MpSuchSemika': 'Sucha Beskidzka',
#  'MpSzarowSpok': 'Szarów',
#  'MpSzarowWIOS1901': 'Szarów',
#  'MpSzarowWIOS1908': 'Szarów',
#  'MpSzczawJanaMOB': 'Szczawnica',
#  'MpSzczawParkMOB': 'Szczawnica',
#  'MpSzymbaGorl': 'Szymbark',
#  'MpTarBitStud': 'Tarnów',
#  'MpTarnowWIOSSoli6303': 'Tarnów',
#  'MpTarnowWSSEMosc6301': 'Tarnów',
#  'MpTarnowWSSEWest6302': 'Tarnów',
#  'MpTarRoSitko': 'Tarnów',
#  'MpTrzebiWIOSPils0303': 'Trzebinia',
#  'MpTrzebOsZWM': 'Trzebinia',
#  'MpTuchChopin': 'Tuchów',
#  'MpWadowiBalyMOB': 'Wadowice',
#  'MpWadowiWIOSPSka1805': 'Wadowice',
#  'MpWadowiWIOSPska1807': 'Wadowice',
#  'MpWadowiWIOSTeat1802': 'Wadowice',
#  'MpWielDembowMOB': 'Wieliczka',
#  'MpWielicWIOSOSP1902': 'Wieliczka',
#  'MpWolbroWIOSFabr1204': 'Wolbrom',
#  'MpWysowaParkMOB': 'Uście Gorlickie Wysowa',
#  'MpWysowaWSSE0502': 'Uście Gorlickie Wysowa',
#  'MpZabieWapie': 'Zabierzów',
#  'MpZakopaSien': 'Zakopane',
#  'MzBelsIGFPAN': 'Belsk Duży',
#  'MzBialaKmiciMOB': 'Biała',
#  'MzCiechSienkWSSE': 'Ciechanów',
#  'MzCiechStrazacka': 'Ciechanów',
#  'MzGostMajaWSSE': 'Gostynin',
#  'MzGranicaKPN': 'Granica',
#  'MzGrodziskWSSE': 'Grodzisk Mazowiecki',
#  'MzGutyDuCzer': 'Guty Duże',
#  'MzKonJezWieMOB': 'Konstancin-Jeziorna',
#  'MzKonJezZero': 'Konstancin-Jeziorna',
#  'MzKonJezZrodWSSE': 'Konstancin-Jeziorna',
#  'MzKozienSwierWSSE': 'Kozienice',
#  'MzLegionBronWSSE': 'Legionowo',
#  'MzLegZegrzyn': 'Legionowo',
#  'MzMakMMickWSSE': 'Maków Mazowiecki',
#  'MzMinMazKaziMOB': 'Mińsk Mazowiecki',
#  'MzMinskKilinWSSE': 'Mińsk Mazowiecki',
#  'MzMinskKoscWSSE': 'Mińsk Mazowiecki',
#  'MzMlawaMajaWSSE': 'Mława',
#  'MzMlawOrdona': 'Mława',
#  'MzNowDwChemWSSE': 'Nowy Dwór Mazowiecki',
#  'MzOstMazSikorWSSE': 'Ostrów Mazowiecka',
#  'MzOstroHalle': 'Ostrołęka',
#  'MzOstrolKoscWSSE': 'Ostrołęka',
#  'MzOstrolTargowa': 'Ostrołęka',
#  'MzOtwoBrzozo': 'Otwock',
#  'MzOtwockBrzozWSSE': 'Otwock',
#  'MzPiaseczDworWSSE': 'Piaseczno',
#  'MzPiasPulask': 'Piastów',
#  'MzPiastWarszWSSE': 'Piastów',
#  'MzPionkiSienWSSE': 'Pionki',
#  'MzPlockJasnaWSSE': 'Płock',
#  'MzPlockKolegWSSE': 'Płock',
#  'MzPlockKolodWSSE': 'Płock',
#  'MzPlockLaczWSSE': 'Płock',
#  'MzPlockOpsis': 'Płock',
#  'MzPlockPiaskaWSSE': 'Płock',
#  'MzPlockPKN1': 'Trzepowo',
#  'MzPlockPKN2': 'Maszewo Duże',
#  'MzPlockPKN3': 'Chełpowo',
#  'MzPlocKroJad': 'Płock',
#  'MzPlocMiReja': 'Płock',
#  'MzPlonskSienWSSE': 'Płońsk',
#  'MzPruszKraszeWSSE': 'Pruszków',
#  'MzPruszMajWSSE': 'Pruszków',
#  'MzPultuskMicMOB': 'Pułtusk',
#  'MzPultusKoscWSSE': 'Pułtusk',
#  'MzPultusMajaWSSE': 'Pułtusk',
#  'MzRad25Czerw': 'Radom',
#  'MzRadHallera': 'Radom',
#  'MzRadomAlekWSSE': 'Radom',
#  'MzRadomCzWSSE': 'Radom',
#  'MzRadomLubonWSSE': 'Radom',
#  'MzRadomPulask': 'Radom',
#  'MzRadTochter': 'Radom',
#  'MzSiedChrobWSSE': 'Siedlce',
#  'MzSiedKonars': 'Siedlce',
#  'MzSiedPodlasWSSE': 'Siedlce',
#  'MzSiedPoniatWSSE': 'Siedlce',
#  'MzSiedSienkWSSE': 'Siedlce',
#  'MzSiedStarowWSSE': 'Siedlce',
#  'MzSiedWoszczWSSE': 'Siedlce',
#  'MzSierpcPiastWSSE': 'Sierpc',
#  'MzSierWiosnyMOB': 'Sierpc',
#  'MzSochPlocWSSE': 'Sochaczew',
#  'MzSochSierpWSSE': 'Sochaczew',
#  'MzSokPodSierpWSSE': 'Sokołów Podlaski',
#  'MzTluszczJKiel': 'Tłuszcz',
#  'MzWarAKrzywo': 'Warszawa',
#  'MzWarAKrzywWSSE': 'Warszawa',
#  'MzWarAlNiepo': 'Warszawa',
#  'MzWarBajkowa': 'Warszawa',
#  'MzWarChrosci': 'Warszawa',
#  'MzWarKondrat': 'Warszawa',
#  'MzWarMarszal': 'Warszawa',
#  'MzWarMeteo': 'Warszawa',
#  'MzWarPodlesn': 'Warszawa',
#  'MzWarPorajow': 'Warszawa',
#  'MzWarPuszSol': 'Warszawa',
#  'MzWarszAlJerozol': 'Warszawa',
#  'MzWarszArmLudWSSE': 'Warszawa',
#  'MzWarszBednarWSSE': 'Warszawa',
#  'MzWarszBernWoda': 'Warszawa',
#  'MzWarszBialobWSSE': 'Warszawa',
#  'MzWarszBorKomWSSE': 'Warszawa',
#  'MzWarszHertzaWSSE': 'Warszawa',
#  'MzWarszKochanWSSE': 'Warszawa',
#  'MzWarszKrucza': 'Warszawa',
#  'MzWarszLazurowa': 'Warszawa',
#  'MzWarszOskLanWSSE': 'Warszawa',
#  'MzWarszSGGW': 'Warszawa',
#  'MzWarszSuwalWSSE': 'Warszawa',
#  'MzWarszZelazWSSE': 'Warszawa',
#  'MzWarTolstoj': 'Warszawa',
#  'MzWarWokalna': 'Warszawa',
#  'MzWarZeganWSSE': 'Warszawa',
#  'MzWolOgrodowa': 'Wołomin',
#  'MzWolomLegionWSSE': 'Wołomin',
#  'MzWyszDaszynWSSE': 'Wyszków',
#  'MzZwolenWSSE': 'Zwoleń',
#  'MzZyrardMoniuszWSSE': 'Żyrardów',
#  'MzZyraRoosev': 'Żyrardów',
#  'OpBrzeg101': 'Brzeg',
#  'OpBrzegPoprz': 'Brzeg',
#  'OpGlubKochan': 'Głubczyce',
#  'OpGlubRatusz': 'Głubczyce',
#  'OpGora12728': 'Góra Św. Anny',
#  'OpJanusz12394': 'Januszkowice',
#  'OpKKozBSmial': 'Kędzierzyn-Koźle',
#  'OpKkozle243': 'Kędzierzyn-Koźle',
#  'OpKkozle61': 'Kędzierzyn-Koźle',
#  'OpKkozleSP10': 'Kędzierzyn-Koźle',
#  'OpKkozleSP3': 'Kędzierzyn-Koźle',
#  'OpKkozleSP7': 'Kędzierzyn-Koźle',
#  'OpKlucz227': 'Kluczbork',
#  'OpKlucz235': 'Kluczbork',
#  'OpKluczMicki': 'Kluczbork',
#  'OpKrap3Maja': 'Krapkowice',
#  'OpNamys2pyl': 'Namysłów',
#  'OpNysa237': 'Nysa',
#  'OpNysaRodzie': 'Nysa',
#  'OpOlesno3pyl': 'Olesno',
#  'OpOlesSlowac': 'Olesno',
#  'OpOpole244': 'Opole',
#  'OpOpole246': 'Opole',
#  'OpOpole45': 'Opole',
#  'OpOpole45p': 'Opole',
#  'OpOpoleKoszy': 'Opole',
#  'OpOpoleMinor': 'Opole',
#  'OpOpoleOsAKr': 'Opole',
#  'OpPrud189': 'Prudnik',
#  'OpPrud189p': 'Prudnik',
#  'OpPrudPodgor': 'Prudnik',
#  'OpSkozleSP5': 'Stare Koźle',
#  'OpStrzel239': 'Strzelce Opolskie',
#  'OpStrzel247': 'Strzelce Opolskie',
#  'OpStrzOpWyszMOB': 'Strzelce Opolskie',
#  'OpZdze12392': 'Zdzieszowice',
#  'OpZdziePiast': 'Zdzieszowice',
#  'PdAugSzpitalna': 'Augustów',
#  'PdAugustowUz': 'Augustów',
#  'PdAugustoZdrMOB': 'Augustów',
#  'PdBialAlPils': 'Białystok',
#  'PdBialPPiech': 'Białystok',
#  'PdBialPulPie': 'Białystok',
#  'PdBialUpalna': 'Białystok',
#  'PdBialWarsza': 'Białystok',
#  'PdBialWaszyn': 'Białystok',
#  'PdBialyBroniewsk': 'Białystok',
#  'PdBialyLegionowa': 'Białystok',
#  'PdBialyLegionowa8': 'Białystok',
#  'PdBialyPorzeczkowa': 'Białystok',
#  'PdBialyWarszaw': 'Białystok',
#  'PdBiePodKosciuszki': 'Bielsk Podlaski',
#  'PdBorsukowiz': 'Borsukowizna',
#  'PdGrajewKonsty3M': 'Grajewo',
#  'PdGrajewoWPoMOB': 'Grajewo',
#  'PdGrajNowickiego': 'Grajewo',
#  'PdHajnowkJagMOB': 'Hajnówka',
#  'PdLomSikorsk': 'Łomża',
#  'PdLomzaKopernika16': 'Łomża',
#  'PdLomzaSadowa': 'Łomża',
#  'PdSiemPilsudskiego': 'Siemiatycze',
#  'PdSokol1Maja': 'Sokółka',
#  'PdSuw1Maja': 'Suwałki',
#  'PdSuwPulask2': 'Suwałki',
#  'PdSuwPulaski': 'Suwałki',
#  'PdZambObronZamb': 'Zambrów',
#  'PkBoguchAngeMOB': 'Boguchwała',
#  'PkCzarnaWSSENafGaz': 'Czarna',
#  'PkDebicaWSSEParkow': 'Dębica',
#  'PkDebiGrottg': 'Dębica',
#  'PkGorzycWSSEKEN': 'Gorzyce',
#  'PkHorZdrParkMOB': 'Horyniec-Zdrój',
#  'PkHorZdrWSSESobies': 'Horyniec-Zdrój',
#  'PkIwonZdrRab': 'Iwonicz-Zdrój',
#  'PkIwZdrWSSEToros': 'Iwonicz-Zdrój',
#  'PkJarosPruch': 'Jarosław',
#  'PkJarosWIOSJanPawII': 'Jarosław',
#  'PkJarosWSSE3Maja': 'Jarosław',
#  'PkJarosWSSEGrunw': 'Jarosław',
#  'PkJasloSikor': 'Jasło',
#  'PkJasloWIOSFabr': 'Jasło',
#  'PkJasloWIOSFlor': 'Jasło',
#  'PkJasloWIOSFlor2': 'Jasło',
#  'PkJasloWIOSMickiew': 'Jasło',
#  'PkJasloWSSE3Maja': 'Jasło',
#  'PkJasloWSSEFloria': 'Jasło',
#  'PkJasloWSSEKoralew': 'Jasło',
#  'PkJasloWSSESrocz': 'Jasło',
#  'PkJedliTokarMOB': 'Jedlicze',
#  'PkKolbWSSETyszk': 'Kolbuszowa',
#  'PkKomanWSSEOsZdr': 'Komańcza',
#  'PkKrempnaMPN': 'Krempna',
#  'PkKrempWIOSGrab': 'Grab',
#  'PkKrosKletow': 'Krosno',
#  'PkKrosnoWSSEKisiel': 'Krosno',
#  'PkKrosnoWSSEKisielewskiego': 'Krosno',
#  'PkKrosnoWSSELewak': 'Krosno',
#  'PkKrosnoWSSEStasz': 'Krosno',
#  'PkLatosZdrojMOB': 'Latoszyn',
#  'PkLeskoWSSERynek': 'Lesko',
#  'PkLubaczWSSEMickiew': 'Lubaczów',
#  'PkMielBierna': 'Mielec',
#  'PkMielPogodn': 'Mielec',
#  'PkMielSolski': 'Mielec',
#  'PkMielWSSEGrunw': 'Mielec',
#  'PkMielWSSESklodow': 'Mielec',
#  'PkMielZaStre': 'Mielec',
#  'PkNiskoSzkla': 'Nisko',
#  'PkPolanWSSEStPomp': 'Polańczyk',
#  'PkPolanZdrojMOB': 'Polańczyk',
#  'PkPrzemGrunw': 'Przemyśl',
#  'PkPrzemWIOSDolin': 'Przemyśl',
#  'PkPrzemWIOSPDom': 'Przemyśl',
#  'PkPrzemWSSEGlaz': 'Przemyśl',
#  'PkPrzemWSSEMariac': 'Przemyśl',
#  'PkPrzemyslWIOSMick': 'Przemyśl',
#  'PkPrzewWSSERynek': 'Przeworsk',
#  'PkRudnikKoncMOB': 'Rudnik nad Sanem',
#  'PkRymZdrPark': 'Rymanów-Zdrój',
#  'PkRymZdrWSSEZdr': 'Rymanów-Zdrój',
#  'PkRzeszPilsu': 'Rzeszów',
#  'PkRzeszRejta': 'Rzeszów',
#  'PkRzeszSloci': 'Rzeszów',
#  'PkRzeszStarz': 'Rzeszów',
#  'PkRzeszWIOSSzop': 'Rzeszów',
#  'PkRzeszWSSEGrunw': 'Rzeszów',
#  'PkRzeszWSSEPilsud': 'Rzeszów',
#  'PkRzeszWSSEPoniat': 'Rzeszów',
#  'PkRzeszWSSESkubisz': 'Rzeszów',
#  'PkRzeszWSSEWierzb': 'Rzeszów',
#  'PkSanokWSSEJanPawl': 'Sanok',
#  'PkSanokWSSEJezier': 'Sanok',
#  'PkSanokWSSEMickew': 'Sanok',
#  'PkSanoSadowa': 'Sanok',
#  'PkStWolWoPol': 'Stalowa Wola',
#  'PkStWolWSSENiezl': 'Stalowa Wola',
#  'PkTarnDabrow': 'Tarnobrzeg',
#  'PkTarnobWIOSSwBarb': 'Tarnobrzeg',
#  'PkTarnobWSSE1Maja': 'Tarnobrzeg',
#  'PkTarnobWSSEWarszaw': 'Tarnobrzeg',
#  'PkTarnobWSSEWiejs': 'Tarnobrzeg',
#  'PkUsDolWSSEKoper': 'Ustrzyki Dolne',
#  'PkUstDolWSSEBelz': 'Ustrzyki Dolne',
#  'Pm.00.s218m': 'Gdynia',
#  'Pm.00.s231m': 'Sopot',
#  'Pm.00.s234m': 'Gdynia',
#  'Pm.00.s237m': 'Gdynia',
#  'Pm.00.s428m': 'Gdańsk',
#  'Pm.00.s473m': 'Gdańsk',
#  'Pm.00.s476m': 'Gdańsk',
#  'Pm.00.s477m': 'Gdańsk',
#  'Pm.00.s479m': 'Gdańsk',
#  'Pm.01w.01m': 'Gdynia',
#  'Pm.02.s631m': 'Chojnice',
#  'Pm.04.s472m': 'Pruszcz Gdański',
#  'Pm.06.s711m': 'Kościerzyna',
#  'Pm.06.s712m': 'Kościerzyna',
#  'Pm.07.s005m': 'Kwidzyn',
#  'Pm.08.s076m': 'Lębork',
#  'Pm.08.s077m': 'Łeba',
#  'Pm.09.s067m': 'Malbork',
#  'Pm.12.s063m': 'Ustka',
#  'Pm.13.s618m': 'Starogard Gdański',
#  'Pm.14.s512m': 'Tczew',
#  'Pm.15.s128m': 'Wejherowo',
#  'Pm.63.s073m': 'Słupsk',
#  'Pm.63.s079m': 'Słupsk',
#  'Pm.63.wDSMm': 'Słupsk',
#  'Pm.a09a': 'Gdynia',
#  'Pm.aw07m': 'Tczew',
#  'Pm14TCZEw06m': 'Tczew',
#  'PmBytowMila1MOB': 'Bytów',
#  'PmChojPlEmsdMOB': 'Chojnice',
#  'PmGac': 'Gać',
#  'PmGdaGleboka': 'Gdańsk',
#  'PmGdaGrunwalTMP': 'Gdańsk',
#  'PmGdaKacze02': 'Gdańsk',
#  'PmGdaLeczk81': 'Gdańsk',
#  'PmGdaLeczkow': 'Gdańsk',
#  'PmGdaOstrz05': 'Gdańsk',
#  'PmGdaPowWars': 'Gdańsk',
#  'PmGdaPowWiel': 'Gdańsk',
#  'PmGdaWyzwole': 'Gdańsk',
#  'PmGdyJozBema': 'Gdynia',
#  'PmGdyPorebsk': 'Gdynia',
#  'PmGdySzafran': 'Gdynia',
#  'PmGdyWendy10': 'Gdynia',
#  'PmKartWejher': 'Kartuzy',
#  'PmKosTargowa': 'Kościerzyna',
#  'PmKwiSportow': 'Kwidzyn',
#  'PmLebaRabka1': 'Łeba',
#  'PmLebMalczew': 'Lębork',
#  'PmLinieKosci': 'Liniewko Kościerskie',
#  'PmMalMickiew': 'Malbork',
#  'PmSlupKniazi': 'Słupsk',
#  'PmSlupOrzesz': 'Słupsk',
#  'PmSopBiPlowc': 'Sopot',
#  'PmSopBitPl06': 'Sopot',
#  'PmStaGdaLubi': 'Starogard Gdański',
#  'PmTczeTarg07': 'Tczew',
#  'PmUstkaRybacMOB': 'Ustka',
#  'PmWejhDworco': 'Wejherowo',
#  'PmWejhPlWejh': 'Wejherowo',
#  'PmWladywHallera': 'Władysławowo',
#  'SkBuskoRzew': 'Busko-Zdrój',
#  'SkBuskoWios': 'Busko-Zdrój',
#  'SkBuskRokosz': 'Busko-Zdrój',
#  'SkChecBiaZag': 'Chęciny',
#  'SkGoluUjWody': 'Gołuchów',
#  'SkJedrMieszkMOB': 'Jędrzejów',
#  'SkKaziWSzkolMOB': 'Kazimierza Wielka',
#  'SkKielGalcz': 'Kielce',
#  'SkKielIXWiek': 'Kielce',
#  'SkKielJagiel': 'Kielce',
#  'SkKielJagielWSSE': 'Kielce',
#  'SkKielJurajs': 'Kielce',
#  'SkKielKusoci': 'Kielce',
#  'SkKielTargow': 'Kielce',
#  'SkKielTransp': 'Kielce',
#  'SkKielWarsz1': 'Kielce',
#  'SkKielWarsza': 'Kielce',
#  'SkKonsGranatMOB': 'Końskie',
#  'SkKonskArmKr': 'Końskie',
#  'SkLagowZaploMOB': 'Łagów',
#  'SkMalo11List': 'Małogoszcz',
#  'SkMalogCemen': 'Małogoszcz',
#  'SkMalogCemen2': 'Małogoszcz',
#  'SkMaloSlonec': 'Małogoszcz',
#  'SKNowinyCemen': 'Sitkówka Nowiny',
#  'SkNowiParkow': 'Nowiny',
#  'SkOpatPartyz': 'Opatów',
#  'SkOstrOsSlonMOB': 'Ostrowiec Świętokrzyski',
#  'SkOstrowKatD': 'Ostrowiec Świętokrzyski',
#  'SkOstrowOsSl': 'Ostrowiec Świętokrzyski',
#  'SkOstrowSams': 'Ostrowiec Świętokrzyski',
#  'SkOstrowWios': 'Ostrowiec Świętokrzyski',
#  'SkOzarOsWzgo': 'Ożarów',
#  'SkOzarowMiec': 'Mieczysławów',
#  'SkOzarowOsWz': 'Ożarów',
#  'SkPincz1MajaMOB': 'Pińczów',
#  'SkPolaRuszcz': 'Połaniec',
#  'SkSandomMac': 'Sandomierz',
#  'SkSandZielnaMOB': 'Sandomierz',
#  'SkSkarz1MajaMOB': 'Skarżysko-Kamienna',
#  'SkSkarZielnaMOB': 'Skarżysko-Kamienna',
#  'SkSkarzSlow': 'Skarżysko-Kamienna',
#  'SkSolecZdroj': 'Solec Zdrój',
#  'SkStaracMur': 'Starachowice',
#  'SkStaracZlota': 'Starachowice',
#  'SkStaraZlota': 'Starachowice',
#  'SkSwietKrzyz': 'Święty Krzyż',
#  'SkTrzciOsiek': 'Trzcianka',
#  'SkWloszKilinMOB': 'Włoszczowa',
#  'SlBedziBedz_kosci': 'Będzin',
#  'SlBielbBiel_broni': 'Bielsko-Biała',
#  'SlBielbBiel_langi': 'Bielsko-Biała',
#  'SlBielKossak': 'Bielsko-Biała',
#  'SlBielPartyz': 'Bielsko-Biała',
#  'SlBielSterni': 'Bielsko-Biała',
#  'SlBytomByto_modrz': 'Bytom',
#  'SlBytomByto_parko': 'Bytom',
#  'SlChorzChor_bator': 'Chorzów',
#  'SlCiesChopin': 'Cieszyn',
#  'SlCiesMickie': 'Cieszyn',
#  'SlCieszCies_dojaz': 'Cieszyn',
#  'SlCieszCies_rynek': 'Cieszyn',
#  'SlCzerKopaln': 'Czerwionka-Leszczyny',
#  'SlCzestCzes_arkra': 'Częstochowa',
#  'SlCzestCzes_biega': 'Częstochowa',
#  'SlCzestCzes_boyaz': 'Częstochowa',
#  'SlCzestCzes_rzasa': 'Częstochowa',
#  'SlCzestoArmK': 'Częstochowa',
#  'SlCzestoBacz': 'Częstochowa',
#  'SlCzestoZana': 'Częstochowa',
#  'SlDabroDabr_legio': 'Dąbrowa Górnicza',
#  'SlDabroDabr_ziolo': 'Dąbrowa Górnicza',
#  'SlDabroTysia': 'Dąbrowa Górnicza',
#  'SlGliwicMewy': 'Gliwice',
#  'SlGliwiGliw_kujaw': 'Gliwice',
#  'SlGoczaUzdroMOB': 'Goczałkowice-Zdrój',
#  'SlGodGliniki': 'Godów',
#  'SlJastrJast_harce': 'Jastrzębie-Zdrój',
#  'SlJastrZdroj': 'Jastrzębie-Zdrój',
#  'SlJaworJawo_poczt': 'Jaworzno',
#  'SlKatoKossut': 'Katowice',
#  'SlKatoPlebA4': 'Katowice',
#  'SlKatowKato_racib': 'Katowice',
#  'SlKatowKato_weste': 'Katowice',
#  'SlKlobuKlob_zamko': 'Kłobuck',
#  'SlKnurJedNar': 'Knurów',
#  'SlKuzniGliw_wiejs': 'Kuźnia Nieborowicka',
#  'SlLubliLubl_dworc': 'Lubliniec',
#  'SlLublPiasko': 'Lubliniec',
#  'SlLublSzymal': 'Lubliniec',
#  'SlMiastMias_norwi': 'Miasteczko Śląskie',
#  'SlMiastMias_wycis': 'Miasteczko Śląskie',
#  'SlMiastMias_zygli': 'Miasteczko Śląskie',
#  'SlMyszkMysz_straz': 'Myszków',
#  'SlMyszMiedzi': 'Myszków',
#  'SlPiekaPiek_darwi': 'Piekary Śląskie',
#  'SlPiekaPiek_party': 'Piekary Śląskie',
#  'SlPszczBator': 'Pszczyna',
#  'SlPszczBoged': 'Pszczyna',
#  'SlRaciborzWPMOB': 'Racibórz',
#  'SlRacibRaci_boruc': 'Borucin',
#  'SlRacibRaci_studz': 'Racibórz',
#  'SlRacibRaci_towar': 'Racibórz',
#  'SlRudasRuda_1maja': 'Ruda Śląska',
#  'SlRybniBorki': 'Rybnik',
#  'SlRybniRybn_janie': 'Rybnik',
#  'SlRybniRybn_szafr': 'Rybnik',
#  'SlSosnoLubel': 'Sosnowiec',
#  'SlSosnoSosn_narut': 'Sosnowiec',
#  'SlTarnoLitew': 'Tarnowskie Góry',
#  'SlTychyTolst': 'Tychy',
#  'SlUstroCies_sanat': 'Ustroń',
#  'SlUstronSana': 'Ustroń',
#  'SlWodzGalczy': 'Wodzisław Śląski',
#  'SlWodziWodz_bogum': 'Wodzisław Śląski',
#  'SlWojkoBedz_pader': 'Wojkowice',
#  'SlZabrzZabr_3maja': 'Zabrze',
#  'SlZabrzZabr_wolno': 'Zabrze',
#  'SlZabSkloCu2': 'Zabrze',
#  'SlZabSkloCur': 'Zabrze',
#  'SlZawGalczyn': 'Zawiercie',
#  'SlZawieZawi_listo': 'Zawiercie',
#  'SlZawieZawi_pilsu': 'Zawiercie',
#  'SlZawSkloCur': 'Zawiercie',
#  'SlZlotPotLes': 'Złoty Potok',
#  'SlZorymZory_wojsk': 'Żory',
#  'SlZorySikor2': 'Żory',
#  'SlZorySikors': 'Żory',
#  'SlZywieKoper': 'Żywiec',
#  'SlZywieSlowa': 'Żywiec',
#  'SlZywieZywi_krasi': 'Żywiec',
#  'WmBartoWSSE_Boh_War': 'Bartoszyce',
#  'WmBiskupMickMOB': 'Biskupiec',
#  'WmDzialdWSSE_Biedraw': 'Działdowo',
#  'WmDzialPolnaMOB': 'Działdowo',
#  'WmElbBazynsk': 'Elbląg',
#  'WmElblagWSSE_Hetma': 'Elbląg',
#  'WmElblagWSSE_Kalen': 'Elbląg',
#  'WmElblagWSSE_Krole': 'Elbląg',
#  'WmElblagWSSE_Zajchow': 'Elbląg',
#  'WmElk_WSSE_Toru': 'Ełk',
#  'WmElkStadion': 'Ełk',
#  'WmElkWIOS_PM10': 'Ełk',
#  'WmGizyckWIOS_Wodoc': 'Giżycko',
#  'WmGizyckWSSE_Suwals': 'Giżycko',
#  'WmGlitajn': 'Glitajny',
#  'WmGoldJacwie': 'Gołdap',
#  'WmGoldUzdrowMOB': 'Gołdap',
#  'WmIlawAnders': 'Iława',
#  'WmIlawaWSSE_Anders': 'Iława',
#  'WmKetrWojPolMOB': 'Kętrzyn',
#  'WmKetrzWSSE_Pilsud': 'Kętrzyn',
#  'WmKorszeR': 'Korsze',
#  ...}

# %%
mapped = {}
for rok in lata:
    mapped[rok] = mapuj_kolumny_z_podgladem(hdr[rok], old2new)
# Out:
#  Zmienione kolumny:
#    PdBialWaszyn  →  PdBialUpalna
#    PmGdaLeczk08  →  PmGdaLeczkow
#    PmKosTargo12  →  PmKosTargowa
#    ZpSzczAndr01  →  ZpSzczAndrze
#    ZpSzczPils02  →  ZpSzczPilsud
#  Zmienione kolumny:
#    MzKonJezMos  →  MzKonJezWieMOB
#    PdBialWaszyn  →  PdBialUpalna
#    PdSuwPulaskp  →  PdSuwPulask2
#    PmGdaLeczk08  →  PmGdaLeczkow
#    PmKosTargo12  →  PmKosTargowa
#    ZpSzczAndr01  →  ZpSzczAndrze
#    ZpSzczPils02  →  ZpSzczPilsud
#  Zmienione kolumny:
#    PdBialWaszyn  →  PdBialUpalna
#  Żadna kolumna nie wymagała zmiany.

# %%
mapped_proc = {}

for rok in lata:
    df_dt = ensure_datetime(mapped[rok])
    df_shift = shift_midnight_to_prev_day(df_dt)
    mapped_proc[rok] = df_shift
# Out:
# Kolumna Data przekonwertowana na datetime (błędne wartości: 0)
# Kolumna Data przekonwertowana na datetime (błędne wartości: 0)
# Kolumna Data przekonwertowana na datetime (błędne wartości: 0)
# Kolumna Data przekonwertowana na datetime (błędne wartości: 0)
# Kolumna Data przekonwertowana na datetime (błędne wartości: 0)
# Kolumna Data przekonwertowana na datetime (błędne wartości: 0)
# Kolumna Data przekonwertowana na datetime (błędne wartości: 0)
# Kolumna Data przekonwertowana na datetime (błędne wartości: 0)

# %%
df_all = pd.concat(
    [mapped_proc[rok] for rok in lata],
    join="inner",
    ignore_index=True
)

# %%
#MultiIndex to po prostu wielopoziomowy indeks — czyli taki, gdzie:
#każda kolumna (lub wiersz) ma kilka warstw etykiet zamiast jednej.
df_all_multi = dodaj_multiindex(df_all, kod2miasto)
df_all_multi.head(10)
# Out:
# Miejscowość                         Jelenia Góra      Wrocław               \
# Kod stacji                     Data DsJelGorOgin DsWrocAlWisn DsWrocWybCon
# 0           2015-01-01 01:00:00.000      151.112           78           50
# 1           2015-01-01 02:00:00.000      262.566           42      33.8244
# 2           2015-01-01 03:00:00.005       222.83           27      28.7215
# 3           2015-01-01 04:00:00.010      210.767           24      20.6891
# 4           2015-01-01 05:00:00.015      191.211           22      22.5335
# 5           2015-01-01 06:00:00.020      114.636           19      18.5107
# 6           2015-01-01 07:00:00.025      21.4669           23      27.4382
# 7           2015-01-01 08:00:00.030      19.7269           32      23.8024
# 8           2015-01-01 09:00:00.035      26.6903           38      32.6736
# 9           2015-01-01 10:00:00.040      25.9544           38       38.217
#
# Miejscowość    Bydgoszcz                    Lublin         Łódź       Zgierz  \
# Kod stacji  KpBydPlPozna KpBydWarszaw LbLubObywate LdLodzCzerni LdZgieMielcz
# 0                   29.2         95.5      71.1012        59.73    58.690689
# 1                   27.1         86.1      95.2582       185.92    44.501255
# 2                    7.9         23.8      49.5078        54.25    24.163937
# 3                    7.1         15.9      60.8468        50.15    19.516039
# 4                    9.2           15      49.3106        39.17    16.850332
# 5                    7.1         12.7      39.6478        27.67    17.975487
# 6                    5.3         11.6      35.6052        19.07    16.226292
# 7                    7.6         11.8      37.1828        20.86    17.142969
# 8                   10.5         13.5      35.0136        21.02    20.666599
# 9                   10.7         17.9      32.0556        19.85    23.429361
#
# Miejscowość Zielona Góra  ...    Białystok     Przemyśl       Gdańsk  \
# Kod stacji  LuZielKrotka  ... PdBialUpalna PkPrzemGrunw PmGdaLeczkow
# 0                    NaN  ...           67      18.9027          NaN
# 1                51.8628  ...          103      15.9257      75.5278
# 2                 15.866  ...           49      16.1709      8.87389
# 3                20.1187  ...           37      16.0252      8.83194
# 4                27.3413  ...           27      15.5498       6.5675
# 5                25.8225  ...           25      15.5701      5.02417
# 6                26.4438  ...           18      15.5822      7.98778
# 7                30.1887  ...           20      17.0011      6.18639
# 8                 33.429  ...           17      17.6716      7.72806
# 9                35.8621  ...           18      18.8466        12.02
#
# Miejscowość  Kościerzyna     Katowice  Złoty Potok      Olsztyn       Kalisz  \
# Kod stacji  PmKosTargowa SlKatoKossut SlZlotPotLes WmOlsPuszkin WpKaliSawick
# 0                    NaN       51.389      49.9464    44.060833         25.5
# 1                    NaN       37.709      45.6291    49.943329         32.5
# 2                    NaN       41.984      49.2093    20.688448         24.3
# 3                22.7895       45.404       53.316    17.437717         24.4
# 4                    NaN       36.854      51.5259    15.532262           25
# 5                    NaN       35.999      42.8913    15.167184         21.1
# 6                    NaN       35.144      40.8906    12.411852         19.2
# 7                     16       36.854      32.7825    12.867249         15.7
# 8                     16       38.564       24.885    11.222319         19.2
# 9                10.0592       42.839      29.6235     8.655203         24.2
#
# Miejscowość     Szczecin
# Kod stacji  ZpSzczAndrze ZpSzczPilsud
# 0                    NaN          NaN
# 1                81.8501      215.379
# 2                25.7333      27.7458
# 3                 18.624      26.5201
# 4                17.6545      31.0393
# 5                27.2269      27.1158
# 6                22.1457      31.1416
# 7                29.5865      29.8682
# 8                31.6656      34.0542
# 9                35.0689      51.6998
#
# [10 rows x 31 columns]

# %%
#2024 był rokiem przystępnym, co wyjaśnia inną liczbę pomiarów w tym roku.

# %%
df_all_multi.to_csv("PM25_all_years.csv", index=False)
print("Zapisano do pliku PM25_all_years.csv")
# Out:
# Zapisano do pliku PM25_all_years.csv

# %% [markdown]
# ### 2. Średnie miesięczne + trend dla miast

# %%
#raz ustawiam lata i miasta co mnie interesują
lata_interesujące = [2015, 2024]
miasta_interesujące = ["Warszawa", "Katowice"]
df_sel = df_all[df_all["Data"].dt.year.isin(lata_interesujące)].copy()

# 2) long: Data | Kod_stacji | PM25
df_long = df_sel.melt(
    id_vars="Data",
    var_name="Kod_stacji",
    value_name="PM25"
)

# 3) miasto z mapowania

df_long["Miasto"] = df_long["Kod_stacji"].map(kod2miasto)
miasta_interesujące = ["Warszawa", "Katowice"]
# 4) tylko Warszawa i Katowice
df_wc = df_long[df_long["Miasto"].isin(miasta_interesujące)].copy()

# 5) średnie miesięczne po wszystkich stacjach w mieście
monthly_city = (
    df_wc
    .groupby(
        [
            df_wc["Data"].dt.year.rename("Rok"),
            df_wc["Data"].dt.month.rename("Miesiac"),
            "Miasto"
        ]
    )["PM25"]
    .mean()
    .reset_index()
)

monthly_city.head()
# Out:
#     Rok  Miesiac    Miasto       PM25
# 0  2015        1  Katowice  31.268241
# 1  2015        1  Warszawa  24.939978
# 2  2015        2  Katowice  56.245705
# 3  2015        2  Warszawa  44.536903
# 4  2015        3  Katowice  39.502545

# %%
#wyciągam warszawę i katowice (już w vis.py)
plot_monthly_pm25(
    monthly_city
)

# %% [markdown]
# Wykres przedstawia średnie miesięczne stężenia pyłu PM2.5
# [
# 𝜇
# 𝑔
# /
# 𝑚
# 3
# ]
# [μg/m
# 3
# ] dla dwóch miast: Katowic i Warszawy, porównując dwa lata: 2015 oraz 2024. Oś pozioma odpowiada kolejnym miesiącom roku
# (
# 1
# –
# 12
# )
# (1–12), natomiast oś pionowa przedstawia średnie miesięczne stężenie PM2.5.
#
# Dla obu miast i analizowanych lat widoczna jest wyraźna sezonowość stężeń PM2.5. Najwyższe wartości występują w miesiącach zimowych (styczeń–marzec oraz listopad–grudzień), natomiast najniższe w okresie letnim (czerwiec–sierpień). Zjawisko to wynika głównie z intensyfikacji emisji w sezonie grzewczym oraz gorszych warunków dyspersji zanieczyszczeń zimą.
#
# Porównanie lat wskazuje na istotne obniżenie poziomu stężeń PM2.5 w 2024 roku w stosunku do 2015 roku, szczególnie w Katowicach. W 2015 roku Katowice charakteryzowały się bardzo wysokimi stężeniami zimą, przekraczającymi miejscami
# 50
#
# 𝜇
# 𝑔
# /
# 𝑚
# 3
# 50μg/m
# 3
# , podczas gdy w 2024 roku wartości te są wyraźnie niższe i nie przekraczają około
# 30
#
# 𝜇
# 𝑔
# /
# 𝑚
# 3
# 30μg/m
# 3
# . W Warszawie również obserwuje się spadek stężeń w 2024 roku, choć skala zmian jest mniejsza niż w przypadku Katowic.

# %% [markdown]
# ### 3. Heatmapa miesięcznych średnich
# Dla każdej miejscowości przedstaw heatmapę średnich miesięcznych stężeń PM2.5 w latach lat 2014, 2019 i 2024 (oś X – miesiąc, oś Y – rok). Uśrednij wartości po wszystkich stacjach w danej miejscowości. Każdy panel (facet) ma odpowiadać jednej miejscowości. Dołącz interpretację obserwowanych wyników.

# %%
lata_do_heatmapy = [2015, 2018, 2021, 2024]
df_sel = df_all[df_all["Data"].dt.year.isin(lata_do_heatmapy)].copy()
df_long = df_sel.melt(
    id_vars="Data",
    var_name="Kod_stacji",
    value_name="PM25"
)
df_long["PM25"] = pd.to_numeric(df_long["PM25"], errors="coerce")  #żeby był typ numeric

df_long["Miasto"] = df_long["Kod_stacji"].map(kod2miasto)
df_long["Miasto"].isna().sum()
monthly_city = (
    df_long
    .groupby(
        [
            df_long["Data"].dt.year.rename("Rok"),
            df_long["Data"].dt.month.rename("Miesiac"),
            "Miasto"
        ]
    )["PM25"]
    .mean()
    .reset_index()
)

monthly_city.head()
# Out:
#     Rok  Miesiac        Miasto       PM25
# 0  2015        1     Białystok  22.458108
# 1  2015        1     Bydgoszcz  23.300085
# 2  2015        1        Gdańsk  15.260864
# 3  2015        1  Jelenia Góra  24.520156
# 4  2015        1        Kalisz  32.039201

# %%
plot_pm25_heatmaps(monthly_city)

# %% [markdown]
# Interpretacja wyników:
#
# W większości miejscowości można zaobserwować stosunkowo podobne trendy (analogiczne do tych zaobserwowanych w zad. 2).
# W miesiącach zimowych występują najwyższe stężenia PM2.5 - prawdopodobnie powiązane z ogrzewaniem domów.
# W późniejszych latach są stabilnie niższe stężenia PM2.5 - potencjalnie związane z modernizacją systemów grzewczych i zaostrzeniem norm emisji. Pojawiające się w niektórych panelach białe pola odpowiadają brakom danych pomiarowych dla danej kombinacji roku i miesiąca, powstały przez niekompletność danych źródłowych
